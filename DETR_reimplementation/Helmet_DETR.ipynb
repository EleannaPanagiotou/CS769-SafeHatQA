# %% [markdown]
# # Convert to .py
#
# jupyter nbconvert --to script Helmet_DETR.ipynb

# %%
from pathlib import Path
import os
import numpy as np

import torch, torchvision
print(torch.__version__, torch.cuda.is_available())
torch.set_grad_enabled(False)
# Out:
# 2.5.1+cu124 True

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import pylab
pylab.rcParams['figure.figsize'] = (10.0, 8.0)

# %%
first_class_index = 1
assert(first_class_index in [0, 1])

if first_class_index == 0:

  # There is one class, balloon, with ID n°0.

  num_classes = 3

  finetuned_classes = [
      'helmet',
      'head',
      'person'
  ]

  # The `no_object` class will be automatically reserved by DETR with ID equal
  # to `num_classes`, so ID n°1 here.

else:

  # There is one class, balloon, with ID n°1.
  #
  # However, DETR assumes that indexing starts with 0, as in computer science,
  # so there is a dummy class with ID n°0.
  # Caveat: this dummy class is not the `no_object` class reserved by DETR.

  num_classes = 2

  finetuned_classes = [
      'N/A',  'helmet', 'head'
  ]

  # The `no_object` class will be automatically reserved by DETR with ID equal
  # to `num_classes`, so ID n°2 here.

print('First class index: {}'.format(first_class_index))
print('Parameter num_classes: {}'.format(num_classes))
print('Fine-tuned classes: {}'.format(finetuned_classes))
# Out:
# First class index: 1
# Parameter num_classes: 2
# Fine-tuned classes: ['N/A', 'helmet', 'head']

# %%
# %%

# %cd /content/
# !rm -rf detr
# !git clone https://github.com/woctezuma/detr.git

# %cd detr/

# !git checkout finetune
# Out:
# Cloning into 'detr'...
# remote: Enumerating objects: 265, done.
# remote: Total 265 (delta 0), reused 0 (delta 0), pack-reused 265 (from 1)
# Receiving objects: 100% (265/265), 325.44 KiB | 3.87 MiB/s, done.
# Resolving deltas: 100% (127/127), done.
# /home/epanagiotou/AdvancedNLP/DETR_reimplementation/detr
# Already on 'finetune'
# Your branch is up to date with 'origin/finetune'.

# %%
# Get pretrained weights
checkpoint = torch.hub.load_state_dict_from_url(
            url='https://dl.fbaipublicfiles.com/detr/detr-r50-e632da11.pth',
            map_location='cpu',
            check_hash=True)

# Remove class weights
del checkpoint["model"]["class_embed.weight"]
del checkpoint["model"]["class_embed.bias"]

# Save
torch.save(checkpoint,
           '/home/epanagiotou/AdvancedNLP/DETR_reimplementation/detr-r50_no-class-heads.pth')

# %%
# !python main.py \
#   --dataset_file "custom" \
#   --coco_path "/home/lefki/AdvancedNLP/DETR_reimplementation/processed_dataset" \
#   --output_dir "outputs" \
#   --resume "/home/lefki/AdvancedNLP/DETR_reimplementation/detrdetr-r50_no-class-head.pth" \
#   --num_classes $num_classes \
#   --epochs 2

# !python main.py \
  --dataset_file "custom" \
  --coco_path "/home/epanagiotou/AdvancedNLP/DETR_reimplementation/processed_dataset" \
  --output_dir "outputs" \
  --resume "/home/epanagiotou/AdvancedNLP/DETR_reimplementation/detr-r50_no-class-heads.pth" \
  --num_classes $num_classes \
  --epochs 400 \
  --batch_size 8 \
  --lr_drop 150 \
  --lr 1e-6
# Out:
# Not using distributed mode
# git:
#   sha: e891373a8cab93d3719afb0acff28de94c6dc6a3, status: clean, branch: finetune
#
# Namespace(lr=0.01, lr_backbone=1e-05, batch_size=8, weight_decay=0.0001, epochs=400, lr_drop=150, clip_max_norm=0.1, frozen_weights=None, backbone='resnet50', dilation=False, position_embedding='sine', enc_layers=6, dec_layers=6, dim_feedforward=2048, hidden_dim=256, dropout=0.1, nheads=8, num_queries=100, pre_norm=False, masks=False, aux_loss=True, set_cost_class=1, set_cost_bbox=5, set_cost_giou=2, mask_loss_coef=1, dice_loss_coef=1, bbox_loss_coef=5, giou_loss_coef=2, eos_coef=0.1, num_classes=2, dataset_file='custom', coco_path='/home/epanagiotou/AdvancedNLP/DETR_reimplementation/processed_dataset', coco_panoptic_path=None, remove_difficult=False, output_dir='outputs', device='cuda', seed=42, resume='/home/epanagiotou/AdvancedNLP/DETR_reimplementation/detr-r50_no-class-heads.pth', start_epoch=0, eval=False, num_workers=2, world_size=1, dist_url='env://', distributed=False)
# /home/epanagiotou/anaconda3/envs/cs769/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/epanagiotou/anaconda3/envs/cs769/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# number of params: 41279495
# loading annotations into memory...
# Done (t=0.09s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# /home/epanagiotou/AdvancedNLP/DETR_reimplementation/detr/main.py:179: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(args.resume, map_location='cpu')
# Start training
# Epoch: [0]  [  0/437]  eta: 0:08:17  lr: 0.010000  class_error: 47.62  loss: 32.9260 (32.9260)  loss_ce: 1.8369 (1.8369)  loss_bbox: 1.4323 (1.4323)  loss_giou: 2.2443 (2.2443)  loss_ce_0: 1.7920 (1.7920)  loss_bbox_0: 1.4368 (1.4368)  loss_giou_0: 2.1825 (2.1825)  loss_ce_1: 1.8103 (1.8103)  loss_bbox_1: 1.5871 (1.5871)  loss_giou_1: 2.0632 (2.0632)  loss_ce_2: 1.8444 (1.8444)  loss_bbox_2: 1.4567 (1.4567)  loss_giou_2: 2.1828 (2.1828)  loss_ce_3: 1.8481 (1.8481)  loss_bbox_3: 1.4379 (1.4379)  loss_giou_3: 2.2102 (2.2102)  loss_ce_4: 1.8640 (1.8640)  loss_bbox_4: 1.4526 (1.4526)  loss_giou_4: 2.2441 (2.2441)  loss_ce_unscaled: 1.8369 (1.8369)  class_error_unscaled: 47.6190 (47.6190)  loss_bbox_unscaled: 0.2865 (0.2865)  loss_giou_unscaled: 1.1221 (1.1221)  cardinality_error_unscaled: 97.1250 (97.1250)  loss_ce_0_unscaled: 1.7920 (1.7920)  loss_bbox_0_unscaled: 0.2874 (0.2874)  loss_giou_0_unscaled: 1.0912 (1.0912)  cardinality_error_0_unscaled: 96.3750 (96.3750)  loss_ce_1_unscaled: 1.8103 (1.8103)  loss_bbox_1_unscaled: 0.3174 (0.3174)  loss_giou_1_unscaled: 1.0316 (1.0316)  cardinality_error_1_unscaled: 97.2500 (97.2500)  loss_ce_2_unscaled: 1.8444 (1.8444)  loss_bbox_2_unscaled: 0.2913 (0.2913)  loss_giou_2_unscaled: 1.0914 (1.0914)  cardinality_error_2_unscaled: 97.3750 (97.3750)  loss_ce_3_unscaled: 1.8481 (1.8481)  loss_bbox_3_unscaled: 0.2876 (0.2876)  loss_giou_3_unscaled: 1.1051 (1.1051)  cardinality_error_3_unscaled: 97.2500 (97.2500)  loss_ce_4_unscaled: 1.8640 (1.8640)  loss_bbox_4_unscaled: 0.2905 (0.2905)  loss_giou_4_unscaled: 1.1220 (1.1220)  cardinality_error_4_unscaled: 97.1250 (97.1250)  time: 1.1386  data: 0.2942  max mem: 5220
# Epoch: [0]  [ 10/437]  eta: 0:03:00  lr: 0.010000  class_error: 58.33  loss: 44.9375 (45.4257)  loss_ce: 0.4790 (0.6929)  loss_bbox: 3.8208 (3.9998)  loss_giou: 3.0320 (3.0076)  loss_ce_0: 0.5482 (0.6727)  loss_bbox_0: 3.7714 (3.8074)  loss_giou_0: 3.0461 (3.0233)  loss_ce_1: 0.5189 (0.6729)  loss_bbox_1: 3.8268 (3.8202)  loss_giou_1: 3.2560 (3.0713)  loss_ce_2: 0.4962 (0.6489)  loss_bbox_2: 3.5724 (3.8610)  loss_giou_2: 3.0907 (3.0612)  loss_ce_3: 0.4929 (0.7256)  loss_bbox_3: 3.9509 (3.6851)  loss_giou_3: 3.0784 (2.9615)  loss_ce_4: 0.5330 (0.7746)  loss_bbox_4: 3.8717 (3.9808)  loss_giou_4: 2.9798 (2.9590)  loss_ce_unscaled: 0.4790 (0.6929)  class_error_unscaled: 70.9677 (66.5756)  loss_bbox_unscaled: 0.7642 (0.8000)  loss_giou_unscaled: 1.5160 (1.5038)  cardinality_error_unscaled: 2.7500 (15.8295)  loss_ce_0_unscaled: 0.5482 (0.6727)  loss_bbox_0_unscaled: 0.7543 (0.7615)  loss_giou_0_unscaled: 1.5231 (1.5116)  cardinality_error_0_unscaled: 2.7500 (12.1932)  loss_ce_1_unscaled: 0.5189 (0.6729)  loss_bbox_1_unscaled: 0.7654 (0.7640)  loss_giou_1_unscaled: 1.6280 (1.5356)  cardinality_error_1_unscaled: 2.7500 (11.7386)  loss_ce_2_unscaled: 0.4962 (0.6489)  loss_bbox_2_unscaled: 0.7145 (0.7722)  loss_giou_2_unscaled: 1.5454 (1.5306)  cardinality_error_2_unscaled: 2.8750 (12.4659)  loss_ce_3_unscaled: 0.4929 (0.7256)  loss_bbox_3_unscaled: 0.7902 (0.7370)  loss_giou_3_unscaled: 1.5392 (1.4808)  cardinality_error_3_unscaled: 2.7500 (19.7614)  loss_ce_4_unscaled: 0.5330 (0.7746)  loss_bbox_4_unscaled: 0.7743 (0.7962)  loss_giou_4_unscaled: 1.4899 (1.4795)  cardinality_error_4_unscaled: 2.7500 (19.7955)  time: 0.4225  data: 0.0493  max mem: 7151
# Epoch: [0]  [ 20/437]  eta: 0:02:43  lr: 0.010000  class_error: 65.22  loss: 42.6327 (42.4556)  loss_ce: 0.4256 (0.5630)  loss_bbox: 3.3232 (3.4711)  loss_giou: 2.8443 (2.8668)  loss_ce_0: 0.4433 (0.5626)  loss_bbox_0: 3.0821 (3.3337)  loss_giou_0: 2.7789 (2.8477)  loss_ce_1: 0.4300 (0.5419)  loss_bbox_1: 3.6305 (3.5478)  loss_giou_1: 2.9972 (3.0050)  loss_ce_2: 0.4217 (0.5314)  loss_bbox_2: 3.5724 (3.6638)  loss_giou_2: 2.8845 (2.9754)  loss_ce_3: 0.4259 (0.5691)  loss_bbox_3: 3.8259 (3.6340)  loss_giou_3: 3.0453 (2.9839)  loss_ce_4: 0.4436 (0.6005)  loss_bbox_4: 3.6352 (3.8067)  loss_giou_4: 2.9798 (2.9514)  loss_ce_unscaled: 0.4256 (0.5630)  class_error_unscaled: 70.9677 (67.4486)  loss_bbox_unscaled: 0.6646 (0.6942)  loss_giou_unscaled: 1.4221 (1.4334)  cardinality_error_unscaled: 2.2500 (9.4107)  loss_ce_0_unscaled: 0.4433 (0.5626)  loss_bbox_0_unscaled: 0.6164 (0.6667)  loss_giou_0_unscaled: 1.3895 (1.4238)  cardinality_error_0_unscaled: 2.1250 (7.4583)  loss_ce_1_unscaled: 0.4300 (0.5419)  loss_bbox_1_unscaled: 0.7261 (0.7096)  loss_giou_1_unscaled: 1.4986 (1.5025)  cardinality_error_1_unscaled: 2.2500 (7.2679)  loss_ce_2_unscaled: 0.4217 (0.5314)  loss_bbox_2_unscaled: 0.7145 (0.7328)  loss_giou_2_unscaled: 1.4422 (1.4877)  cardinality_error_2_unscaled: 2.2500 (7.6488)  loss_ce_3_unscaled: 0.4259 (0.5691)  loss_bbox_3_unscaled: 0.7652 (0.7268)  loss_giou_3_unscaled: 1.5227 (1.4919)  cardinality_error_3_unscaled: 2.2500 (11.4702)  loss_ce_4_unscaled: 0.4436 (0.6005)  loss_bbox_4_unscaled: 0.7270 (0.7613)  loss_giou_4_unscaled: 1.4899 (1.4757)  cardinality_error_4_unscaled: 2.2500 (11.4881)  time: 0.3539  data: 0.0255  max mem: 8199
# Epoch: [0]  [ 30/437]  eta: 0:02:33  lr: 0.010000  class_error: 83.33  loss: 37.7864 (40.2652)  loss_ce: 0.4226 (0.5134)  loss_bbox: 3.5850 (3.6648)  loss_giou: 2.8489 (2.9344)  loss_ce_0: 0.4330 (0.5287)  loss_bbox_0: 2.6132 (3.0383)  loss_giou_0: 2.4232 (2.6788)  loss_ce_1: 0.4093 (0.5042)  loss_bbox_1: 3.2791 (3.3946)  loss_giou_1: 2.9150 (2.9236)  loss_ce_2: 0.4131 (0.4980)  loss_bbox_2: 2.9405 (3.2988)  loss_giou_2: 2.7366 (2.8029)  loss_ce_3: 0.4192 (0.5203)  loss_bbox_3: 3.0567 (3.3642)  loss_giou_3: 2.8107 (2.8217)  loss_ce_4: 0.4327 (0.5430)  loss_bbox_4: 3.2407 (3.4348)  loss_giou_4: 2.7717 (2.8007)  loss_ce_unscaled: 0.4226 (0.5134)  class_error_unscaled: 65.2174 (70.4523)  loss_bbox_unscaled: 0.7170 (0.7330)  loss_giou_unscaled: 1.4245 (1.4672)  cardinality_error_unscaled: 2.2500 (7.1694)  loss_ce_0_unscaled: 0.4330 (0.5287)  loss_bbox_0_unscaled: 0.5226 (0.6077)  loss_giou_0_unscaled: 1.2116 (1.3394)  cardinality_error_0_unscaled: 2.1250 (5.8468)  loss_ce_1_unscaled: 0.4093 (0.5042)  loss_bbox_1_unscaled: 0.6558 (0.6789)  loss_giou_1_unscaled: 1.4575 (1.4618)  cardinality_error_1_unscaled: 2.2500 (5.7177)  loss_ce_2_unscaled: 0.4131 (0.4980)  loss_bbox_2_unscaled: 0.5881 (0.6598)  loss_giou_2_unscaled: 1.3683 (1.4015)  cardinality_error_2_unscaled: 2.2500 (5.9758)  loss_ce_3_unscaled: 0.4192 (0.5203)  loss_bbox_3_unscaled: 0.6113 (0.6728)  loss_giou_3_unscaled: 1.4053 (1.4109)  cardinality_error_3_unscaled: 2.2500 (8.5645)  loss_ce_4_unscaled: 0.4327 (0.5430)  loss_bbox_4_unscaled: 0.6481 (0.6870)  loss_giou_4_unscaled: 1.3858 (1.4003)  cardinality_error_4_unscaled: 2.2500 (8.5766)  time: 0.3540  data: 0.0260  max mem: 8686
# Epoch: [0]  [ 40/437]  eta: 0:02:26  lr: 0.010000  class_error: 50.00  loss: 32.8341 (37.9764)  loss_ce: 0.4226 (0.4948)  loss_bbox: 3.3436 (3.4303)  loss_giou: 2.8091 (2.8303)  loss_ce_0: 0.4330 (0.5101)  loss_bbox_0: 2.1755 (2.7807)  loss_giou_0: 2.2549 (2.5476)  loss_ce_1: 0.4111 (0.4890)  loss_bbox_1: 2.3965 (3.1063)  loss_giou_1: 2.3796 (2.7790)  loss_ce_2: 0.4306 (0.4893)  loss_bbox_2: 2.6717 (3.1109)  loss_giou_2: 2.4260 (2.7024)  loss_ce_3: 0.4267 (0.5016)  loss_bbox_3: 2.2834 (3.0721)  loss_giou_3: 2.2971 (2.6806)  loss_ce_4: 0.4533 (0.5231)  loss_bbox_4: 2.6655 (3.2235)  loss_giou_4: 2.5345 (2.7049)  loss_ce_unscaled: 0.4226 (0.4948)  class_error_unscaled: 77.7778 (72.2503)  loss_bbox_unscaled: 0.6687 (0.6861)  loss_giou_unscaled: 1.4045 (1.4151)  cardinality_error_unscaled: 2.2500 (6.0610)  loss_ce_0_unscaled: 0.4330 (0.5101)  loss_bbox_0_unscaled: 0.4351 (0.5561)  loss_giou_0_unscaled: 1.1275 (1.2738)  cardinality_error_0_unscaled: 2.5000 (5.2774)  loss_ce_1_unscaled: 0.4111 (0.4890)  loss_bbox_1_unscaled: 0.4793 (0.6213)  loss_giou_1_unscaled: 1.1898 (1.3895)  cardinality_error_1_unscaled: 2.2500 (4.9726)  loss_ce_2_unscaled: 0.4306 (0.4893)  loss_bbox_2_unscaled: 0.5343 (0.6222)  loss_giou_2_unscaled: 1.2130 (1.3512)  cardinality_error_2_unscaled: 2.2500 (5.1677)  loss_ce_3_unscaled: 0.4267 (0.5016)  loss_bbox_3_unscaled: 0.4567 (0.6144)  loss_giou_3_unscaled: 1.1486 (1.3403)  cardinality_error_3_unscaled: 2.2500 (7.1250)  loss_ce_4_unscaled: 0.4533 (0.5231)  loss_bbox_4_unscaled: 0.5331 (0.6447)  loss_giou_4_unscaled: 1.2673 (1.3525)  cardinality_error_4_unscaled: 2.2500 (7.1311)  time: 0.3452  data: 0.0259  max mem: 8686
# Epoch: [0]  [ 50/437]  eta: 0:02:20  lr: 0.010000  class_error: 75.00  loss: 32.9998 (37.5539)  loss_ce: 0.3998 (0.4726)  loss_bbox: 2.7951 (3.3547)  loss_giou: 2.4479 (2.7613)  loss_ce_0: 0.3906 (0.4818)  loss_bbox_0: 2.8170 (3.2290)  loss_giou_0: 2.4155 (2.6782)  loss_ce_1: 0.4087 (0.4710)  loss_bbox_1: 2.2159 (2.9876)  loss_giou_1: 2.2035 (2.6692)  loss_ce_2: 0.4032 (0.4697)  loss_bbox_2: 2.6717 (3.0503)  loss_giou_2: 2.3381 (2.6394)  loss_ce_3: 0.4161 (0.4827)  loss_bbox_3: 2.2396 (2.9559)  loss_giou_3: 2.1946 (2.5705)  loss_ce_4: 0.4149 (0.5007)  loss_bbox_4: 2.6655 (3.1542)  loss_giou_4: 2.4165 (2.6252)  loss_ce_unscaled: 0.3998 (0.4726)  class_error_unscaled: 83.3333 (75.1128)  loss_bbox_unscaled: 0.5590 (0.6709)  loss_giou_unscaled: 1.2239 (1.3807)  cardinality_error_unscaled: 2.2500 (5.2377)  loss_ce_0_unscaled: 0.3906 (0.4818)  loss_bbox_0_unscaled: 0.5634 (0.6458)  loss_giou_0_unscaled: 1.2078 (1.3391)  cardinality_error_0_unscaled: 2.8750 (5.0172)  loss_ce_1_unscaled: 0.4087 (0.4710)  loss_bbox_1_unscaled: 0.4432 (0.5975)  loss_giou_1_unscaled: 1.1017 (1.3346)  cardinality_error_1_unscaled: 2.2500 (4.3873)  loss_ce_2_unscaled: 0.4032 (0.4697)  loss_bbox_2_unscaled: 0.5343 (0.6101)  loss_giou_2_unscaled: 1.1690 (1.3197)  cardinality_error_2_unscaled: 2.2500 (4.5686)  loss_ce_3_unscaled: 0.4161 (0.4827)  loss_bbox_3_unscaled: 0.4479 (0.5912)  loss_giou_3_unscaled: 1.0973 (1.2853)  cardinality_error_3_unscaled: 2.2500 (6.1373)  loss_ce_4_unscaled: 0.4149 (0.5007)  loss_bbox_4_unscaled: 0.5331 (0.6308)  loss_giou_4_unscaled: 1.2082 (1.3126)  cardinality_error_4_unscaled: 2.2500 (6.1446)  time: 0.3414  data: 0.0253  max mem: 8686
# Epoch: [0]  [ 60/437]  eta: 0:02:16  lr: 0.010000  class_error: 52.94  loss: 34.7862 (36.9496)  loss_ce: 0.3802 (0.4599)  loss_bbox: 2.9829 (3.2758)  loss_giou: 2.4506 (2.7083)  loss_ce_0: 0.3579 (0.4740)  loss_bbox_0: 3.5467 (3.2503)  loss_giou_0: 3.0420 (2.7318)  loss_ce_1: 0.4087 (0.4621)  loss_bbox_1: 2.4466 (2.9464)  loss_giou_1: 2.3733 (2.6439)  loss_ce_2: 0.3790 (0.4552)  loss_bbox_2: 2.5054 (2.9479)  loss_giou_2: 2.2300 (2.5826)  loss_ce_3: 0.4044 (0.4747)  loss_bbox_3: 2.3984 (2.8608)  loss_giou_3: 2.2358 (2.5465)  loss_ce_4: 0.4035 (0.4840)  loss_bbox_4: 2.4068 (3.0335)  loss_giou_4: 2.4632 (2.6120)  loss_ce_unscaled: 0.3802 (0.4599)  class_error_unscaled: 80.0000 (74.8763)  loss_bbox_unscaled: 0.5966 (0.6552)  loss_giou_unscaled: 1.2253 (1.3541)  cardinality_error_unscaled: 1.8750 (4.7889)  loss_ce_0_unscaled: 0.3579 (0.4740)  loss_bbox_0_unscaled: 0.7093 (0.6501)  loss_giou_0_unscaled: 1.5210 (1.3659)  cardinality_error_0_unscaled: 5.8750 (5.3422)  loss_ce_1_unscaled: 0.4087 (0.4621)  loss_bbox_1_unscaled: 0.4893 (0.5893)  loss_giou_1_unscaled: 1.1867 (1.3220)  cardinality_error_1_unscaled: 2.0000 (4.0512)  loss_ce_2_unscaled: 0.3790 (0.4552)  loss_bbox_2_unscaled: 0.5011 (0.5896)  loss_giou_2_unscaled: 1.1150 (1.2913)  cardinality_error_2_unscaled: 2.0000 (4.2049)  loss_ce_3_unscaled: 0.4044 (0.4747)  loss_bbox_3_unscaled: 0.4797 (0.5722)  loss_giou_3_unscaled: 1.1179 (1.2732)  cardinality_error_3_unscaled: 2.1250 (5.5061)  loss_ce_4_unscaled: 0.4035 (0.4840)  loss_bbox_4_unscaled: 0.4814 (0.6067)  loss_giou_4_unscaled: 1.2316 (1.3060)  cardinality_error_4_unscaled: 2.1250 (5.5061)  time: 0.3495  data: 0.0250  max mem: 8686
# Epoch: [0]  [ 70/437]  eta: 0:02:12  lr: 0.010000  class_error: 92.86  loss: 34.2542 (36.4990)  loss_ce: 0.4046 (0.4578)  loss_bbox: 2.6012 (3.1713)  loss_giou: 2.3779 (2.6673)  loss_ce_0: 0.3109 (0.4471)  loss_bbox_0: 3.1217 (3.2464)  loss_giou_0: 2.8616 (2.7422)  loss_ce_1: 0.4094 (0.4502)  loss_bbox_1: 2.8485 (2.9762)  loss_giou_1: 2.5893 (2.6454)  loss_ce_2: 0.3790 (0.4525)  loss_bbox_2: 2.3770 (2.8948)  loss_giou_2: 2.3506 (2.5673)  loss_ce_3: 0.4114 (0.4669)  loss_bbox_3: 2.4194 (2.7939)  loss_giou_3: 2.3428 (2.5137)  loss_ce_4: 0.3820 (0.4713)  loss_bbox_4: 2.2830 (2.9473)  loss_giou_4: 2.5542 (2.5874)  loss_ce_unscaled: 0.4046 (0.4578)  class_error_unscaled: 70.0000 (74.0669)  loss_bbox_unscaled: 0.5202 (0.6343)  loss_giou_unscaled: 1.1890 (1.3337)  cardinality_error_unscaled: 2.2500 (4.4982)  loss_ce_0_unscaled: 0.3109 (0.4471)  loss_bbox_0_unscaled: 0.6243 (0.6493)  loss_giou_0_unscaled: 1.4308 (1.3711)  cardinality_error_0_unscaled: 7.5000 (5.6109)  loss_ce_1_unscaled: 0.4094 (0.4502)  loss_bbox_1_unscaled: 0.5697 (0.5952)  loss_giou_1_unscaled: 1.2946 (1.3227)  cardinality_error_1_unscaled: 2.1250 (3.8592)  loss_ce_2_unscaled: 0.3790 (0.4525)  loss_bbox_2_unscaled: 0.4754 (0.5790)  loss_giou_2_unscaled: 1.1753 (1.2836)  cardinality_error_2_unscaled: 2.5000 (3.9842)  loss_ce_3_unscaled: 0.4114 (0.4669)  loss_bbox_3_unscaled: 0.4839 (0.5588)  loss_giou_3_unscaled: 1.1714 (1.2568)  cardinality_error_3_unscaled: 2.1250 (5.0739)  loss_ce_4_unscaled: 0.3820 (0.4713)  loss_bbox_4_unscaled: 0.4566 (0.5895)  loss_giou_4_unscaled: 1.2771 (1.2937)  cardinality_error_4_unscaled: 2.2500 (5.0827)  time: 0.3583  data: 0.0258  max mem: 8686
# Epoch: [0]  [ 80/437]  eta: 0:02:09  lr: 0.010000  class_error: 79.17  loss: 32.0369 (35.8738)  loss_ce: 0.3959 (0.4512)  loss_bbox: 2.2405 (3.0229)  loss_giou: 2.3474 (2.6484)  loss_ce_0: 0.3004 (0.4448)  loss_bbox_0: 2.7462 (3.1341)  loss_giou_0: 2.7978 (2.7309)  loss_ce_1: 0.4159 (0.4485)  loss_bbox_1: 2.7430 (2.9047)  loss_giou_1: 2.5893 (2.6392)  loss_ce_2: 0.3730 (0.4449)  loss_bbox_2: 2.4622 (2.8517)  loss_giou_2: 2.4432 (2.5708)  loss_ce_3: 0.3747 (0.4522)  loss_bbox_3: 2.2854 (2.7510)  loss_giou_3: 2.4757 (2.5342)  loss_ce_4: 0.3820 (0.4654)  loss_bbox_4: 2.1330 (2.8227)  loss_giou_4: 2.3596 (2.5564)  loss_ce_unscaled: 0.3959 (0.4512)  class_error_unscaled: 65.2174 (72.8237)  loss_bbox_unscaled: 0.4481 (0.6046)  loss_giou_unscaled: 1.1737 (1.3242)  cardinality_error_unscaled: 2.3750 (4.2454)  loss_ce_0_unscaled: 0.3004 (0.4448)  loss_bbox_0_unscaled: 0.5492 (0.6268)  loss_giou_0_unscaled: 1.3989 (1.3654)  cardinality_error_0_unscaled: 6.8750 (5.5525)  loss_ce_1_unscaled: 0.4159 (0.4485)  loss_bbox_1_unscaled: 0.5486 (0.5809)  loss_giou_1_unscaled: 1.2946 (1.3196)  cardinality_error_1_unscaled: 2.1250 (3.6713)  loss_ce_2_unscaled: 0.3730 (0.4449)  loss_bbox_2_unscaled: 0.4924 (0.5703)  loss_giou_2_unscaled: 1.2216 (1.2854)  cardinality_error_2_unscaled: 2.6250 (3.8657)  loss_ce_3_unscaled: 0.3747 (0.4522)  loss_bbox_3_unscaled: 0.4571 (0.5502)  loss_giou_3_unscaled: 1.2379 (1.2671)  cardinality_error_3_unscaled: 2.2500 (4.7330)  loss_ce_4_unscaled: 0.3820 (0.4654)  loss_bbox_4_unscaled: 0.4266 (0.5645)  loss_giou_4_unscaled: 1.1798 (1.2782)  cardinality_error_4_unscaled: 2.3750 (4.8148)  time: 0.3616  data: 0.0259  max mem: 8686
# Epoch: [0]  [ 90/437]  eta: 0:02:05  lr: 0.010000  class_error: 76.47  loss: 31.3944 (35.4010)  loss_ce: 0.4059 (0.4493)  loss_bbox: 1.9750 (2.9086)  loss_giou: 2.2353 (2.6001)  loss_ce_0: 0.4020 (0.4512)  loss_bbox_0: 2.4928 (3.0954)  loss_giou_0: 2.6211 (2.7056)  loss_ce_1: 0.4416 (0.4540)  loss_bbox_1: 2.0548 (2.8160)  loss_giou_1: 2.2134 (2.5745)  loss_ce_2: 0.4568 (0.4593)  loss_bbox_2: 2.1077 (2.7728)  loss_giou_2: 2.3628 (2.5311)  loss_ce_3: 0.3151 (0.4408)  loss_bbox_3: 2.4304 (2.7579)  loss_giou_3: 2.6473 (2.5503)  loss_ce_4: 0.4360 (0.4747)  loss_bbox_4: 1.8991 (2.8025)  loss_giou_4: 2.3913 (2.5569)  loss_ce_unscaled: 0.4059 (0.4493)  class_error_unscaled: 65.2174 (71.7317)  loss_bbox_unscaled: 0.3950 (0.5817)  loss_giou_unscaled: 1.1176 (1.3000)  cardinality_error_unscaled: 2.6250 (4.4739)  loss_ce_0_unscaled: 0.4020 (0.4512)  loss_bbox_0_unscaled: 0.4986 (0.6191)  loss_giou_0_unscaled: 1.3106 (1.3528)  cardinality_error_0_unscaled: 3.1250 (5.2486)  loss_ce_1_unscaled: 0.4416 (0.4540)  loss_bbox_1_unscaled: 0.4110 (0.5632)  loss_giou_1_unscaled: 1.1067 (1.2873)  cardinality_error_1_unscaled: 2.1250 (3.8324)  loss_ce_2_unscaled: 0.4568 (0.4593)  loss_bbox_2_unscaled: 0.4215 (0.5546)  loss_giou_2_unscaled: 1.1814 (1.2656)  cardinality_error_2_unscaled: 2.8750 (3.9712)  loss_ce_3_unscaled: 0.3151 (0.4408)  loss_bbox_3_unscaled: 0.4861 (0.5516)  loss_giou_3_unscaled: 1.3236 (1.2751)  cardinality_error_3_unscaled: 2.5000 (4.7431)  loss_ce_4_unscaled: 0.4360 (0.4747)  loss_bbox_4_unscaled: 0.3798 (0.5605)  loss_giou_4_unscaled: 1.1956 (1.2785)  cardinality_error_4_unscaled: 3.0000 (5.0234)  time: 0.3569  data: 0.0257  max mem: 8686
# Epoch: [0]  [100/437]  eta: 0:02:01  lr: 0.010000  class_error: 61.29  loss: 30.5500 (34.7979)  loss_ce: 0.4308 (0.4494)  loss_bbox: 1.9106 (2.8081)  loss_giou: 2.1992 (2.5566)  loss_ce_0: 0.4051 (0.4415)  loss_bbox_0: 2.6381 (3.0522)  loss_giou_0: 2.6211 (2.7034)  loss_ce_1: 0.4867 (0.4579)  loss_bbox_1: 1.7784 (2.6970)  loss_giou_1: 1.9814 (2.5189)  loss_ce_2: 0.4568 (0.4581)  loss_bbox_2: 2.0015 (2.6991)  loss_giou_2: 2.2045 (2.5067)  loss_ce_3: 0.4151 (0.4448)  loss_bbox_3: 2.4304 (2.7098)  loss_giou_3: 2.4353 (2.5227)  loss_ce_4: 0.4648 (0.4716)  loss_bbox_4: 2.3572 (2.7589)  loss_giou_4: 2.3913 (2.5409)  loss_ce_unscaled: 0.4308 (0.4494)  class_error_unscaled: 72.4138 (71.8749)  loss_bbox_unscaled: 0.3821 (0.5616)  loss_giou_unscaled: 1.0996 (1.2783)  cardinality_error_unscaled: 3.0000 (4.3762)  loss_ce_0_unscaled: 0.4051 (0.4415)  loss_bbox_0_unscaled: 0.5276 (0.6104)  loss_giou_0_unscaled: 1.3106 (1.3517)  cardinality_error_0_unscaled: 3.2500 (5.2933)  loss_ce_1_unscaled: 0.4867 (0.4579)  loss_bbox_1_unscaled: 0.3557 (0.5394)  loss_giou_1_unscaled: 0.9907 (1.2595)  cardinality_error_1_unscaled: 2.7500 (4.1757)  loss_ce_2_unscaled: 0.4568 (0.4581)  loss_bbox_2_unscaled: 0.4003 (0.5398)  loss_giou_2_unscaled: 1.1023 (1.2534)  cardinality_error_2_unscaled: 3.2500 (4.0644)  loss_ce_3_unscaled: 0.4151 (0.4448)  loss_bbox_3_unscaled: 0.4861 (0.5420)  loss_giou_3_unscaled: 1.2177 (1.2614)  cardinality_error_3_unscaled: 4.0000 (4.9282)  loss_ce_4_unscaled: 0.4648 (0.4716)  loss_bbox_4_unscaled: 0.4714 (0.5518)  loss_giou_4_unscaled: 1.1956 (1.2704)  cardinality_error_4_unscaled: 3.1250 (5.3119)  time: 0.3469  data: 0.0256  max mem: 8686
# Epoch: [0]  [110/437]  eta: 0:01:57  lr: 0.010000  class_error: 55.88  loss: 29.6811 (34.2342)  loss_ce: 0.4310 (0.4576)  loss_bbox: 1.6242 (2.7018)  loss_giou: 2.1059 (2.5117)  loss_ce_0: 0.2112 (0.4192)  loss_bbox_0: 2.8541 (3.0974)  loss_giou_0: 2.7497 (2.7191)  loss_ce_1: 0.5050 (0.4652)  loss_bbox_1: 1.6093 (2.5996)  loss_giou_1: 1.9979 (2.4787)  loss_ce_2: 0.4192 (0.4584)  loss_bbox_2: 1.9260 (2.6317)  loss_giou_2: 2.2421 (2.4881)  loss_ce_3: 0.4754 (0.4550)  loss_bbox_3: 1.8965 (2.6308)  loss_giou_3: 2.1511 (2.4843)  loss_ce_4: 0.4082 (0.4726)  loss_bbox_4: 1.8204 (2.6632)  loss_giou_4: 2.1889 (2.4999)  loss_ce_unscaled: 0.4310 (0.4576)  class_error_unscaled: 69.2308 (70.8374)  loss_bbox_unscaled: 0.3248 (0.5404)  loss_giou_unscaled: 1.0529 (1.2559)  cardinality_error_unscaled: 3.2500 (4.4595)  loss_ce_0_unscaled: 0.2112 (0.4192)  loss_bbox_0_unscaled: 0.5708 (0.6195)  loss_giou_0_unscaled: 1.3748 (1.3595)  cardinality_error_0_unscaled: 6.6250 (5.4223)  loss_ce_1_unscaled: 0.5050 (0.4652)  loss_bbox_1_unscaled: 0.3219 (0.5199)  loss_giou_1_unscaled: 0.9989 (1.2394)  cardinality_error_1_unscaled: 4.1250 (4.2264)  loss_ce_2_unscaled: 0.4192 (0.4584)  loss_bbox_2_unscaled: 0.3852 (0.5263)  loss_giou_2_unscaled: 1.1210 (1.2441)  cardinality_error_2_unscaled: 4.0000 (4.2466)  loss_ce_3_unscaled: 0.4754 (0.4550)  loss_bbox_3_unscaled: 0.3793 (0.5262)  loss_giou_3_unscaled: 1.0756 (1.2422)  cardinality_error_3_unscaled: 4.3750 (4.8773)  loss_ce_4_unscaled: 0.4082 (0.4726)  loss_bbox_4_unscaled: 0.3641 (0.5326)  loss_giou_4_unscaled: 1.0944 (1.2500)  cardinality_error_4_unscaled: 3.5000 (5.1374)  time: 0.3543  data: 0.0257  max mem: 8686
# Epoch: [0]  [120/437]  eta: 0:01:53  lr: 0.010000  class_error: 66.67  loss: 27.9522 (33.5645)  loss_ce: 0.4075 (0.4499)  loss_bbox: 1.5981 (2.6198)  loss_giou: 1.9501 (2.4709)  loss_ce_0: 0.2004 (0.4055)  loss_bbox_0: 3.3160 (3.0613)  loss_giou_0: 2.6489 (2.7073)  loss_ce_1: 0.4652 (0.4615)  loss_bbox_1: 1.6093 (2.5128)  loss_giou_1: 1.9703 (2.4368)  loss_ce_2: 0.4341 (0.4543)  loss_bbox_2: 1.8697 (2.5687)  loss_giou_2: 2.2175 (2.4556)  loss_ce_3: 0.4453 (0.4532)  loss_bbox_3: 1.7510 (2.5574)  loss_giou_3: 2.1238 (2.4514)  loss_ce_4: 0.3967 (0.4677)  loss_bbox_4: 1.7176 (2.5820)  loss_giou_4: 1.9864 (2.4483)  loss_ce_unscaled: 0.4075 (0.4499)  class_error_unscaled: 58.3333 (70.1133)  loss_bbox_unscaled: 0.3196 (0.5240)  loss_giou_unscaled: 0.9751 (1.2355)  cardinality_error_unscaled: 2.5000 (4.2820)  loss_ce_0_unscaled: 0.2004 (0.4055)  loss_bbox_0_unscaled: 0.6632 (0.6123)  loss_giou_0_unscaled: 1.3245 (1.3536)  cardinality_error_0_unscaled: 6.8750 (5.5733)  loss_ce_1_unscaled: 0.4652 (0.4615)  loss_bbox_1_unscaled: 0.3219 (0.5026)  loss_giou_1_unscaled: 0.9852 (1.2184)  cardinality_error_1_unscaled: 2.2500 (4.0589)  loss_ce_2_unscaled: 0.4341 (0.4543)  loss_bbox_2_unscaled: 0.3739 (0.5137)  loss_giou_2_unscaled: 1.1087 (1.2278)  cardinality_error_2_unscaled: 2.5000 (4.0940)  loss_ce_3_unscaled: 0.4453 (0.4532)  loss_bbox_3_unscaled: 0.3502 (0.5115)  loss_giou_3_unscaled: 1.0619 (1.2257)  cardinality_error_3_unscaled: 2.3750 (4.6601)  loss_ce_4_unscaled: 0.3967 (0.4677)  loss_bbox_4_unscaled: 0.3435 (0.5164)  loss_giou_4_unscaled: 0.9932 (1.2242)  cardinality_error_4_unscaled: 2.2500 (4.8936)  time: 0.3530  data: 0.0259  max mem: 8686
# Epoch: [0]  [130/437]  eta: 0:01:49  lr: 0.010000  class_error: 85.19  loss: 25.4449 (32.9631)  loss_ce: 0.3731 (0.4470)  loss_bbox: 1.6018 (2.5421)  loss_giou: 1.9363 (2.4330)  loss_ce_0: 0.2900 (0.4058)  loss_bbox_0: 2.0374 (2.9662)  loss_giou_0: 2.4271 (2.6656)  loss_ce_1: 0.3951 (0.4567)  loss_bbox_1: 1.6513 (2.4485)  loss_giou_1: 1.9469 (2.4068)  loss_ce_2: 0.4094 (0.4496)  loss_bbox_2: 1.8475 (2.5020)  loss_giou_2: 2.2175 (2.4355)  loss_ce_3: 0.4149 (0.4491)  loss_bbox_3: 1.7510 (2.5221)  loss_giou_3: 2.1238 (2.4301)  loss_ce_4: 0.4214 (0.4617)  loss_bbox_4: 1.7162 (2.5186)  loss_giou_4: 1.9494 (2.4226)  loss_ce_unscaled: 0.3731 (0.4470)  class_error_unscaled: 59.2593 (69.8305)  loss_bbox_unscaled: 0.3204 (0.5084)  loss_giou_unscaled: 0.9682 (1.2165)  cardinality_error_unscaled: 2.1250 (4.1298)  loss_ce_0_unscaled: 0.2900 (0.4058)  loss_bbox_0_unscaled: 0.4075 (0.5932)  loss_giou_0_unscaled: 1.2136 (1.3328)  cardinality_error_0_unscaled: 4.1250 (5.3607)  loss_ce_1_unscaled: 0.3951 (0.4567)  loss_bbox_1_unscaled: 0.3303 (0.4897)  loss_giou_1_unscaled: 0.9735 (1.2034)  cardinality_error_1_unscaled: 2.1250 (3.9151)  loss_ce_2_unscaled: 0.4094 (0.4496)  loss_bbox_2_unscaled: 0.3695 (0.5004)  loss_giou_2_unscaled: 1.1087 (1.2178)  cardinality_error_2_unscaled: 2.1250 (3.9552)  loss_ce_3_unscaled: 0.4149 (0.4491)  loss_bbox_3_unscaled: 0.3502 (0.5044)  loss_giou_3_unscaled: 1.0619 (1.2150)  cardinality_error_3_unscaled: 2.2500 (4.4981)  loss_ce_4_unscaled: 0.4214 (0.4617)  loss_bbox_4_unscaled: 0.3432 (0.5037)  loss_giou_4_unscaled: 0.9747 (1.2113)  cardinality_error_4_unscaled: 2.2500 (4.6927)  time: 0.3494  data: 0.0258  max mem: 8686
# Epoch: [0]  [140/437]  eta: 0:01:46  lr: 0.010000  class_error: 82.61  loss: 26.7454 (32.5925)  loss_ce: 0.4233 (0.4479)  loss_bbox: 1.6018 (2.4729)  loss_giou: 1.9165 (2.3999)  loss_ce_0: 0.4701 (0.4185)  loss_bbox_0: 1.8430 (2.8959)  loss_giou_0: 2.1816 (2.6398)  loss_ce_1: 0.4150 (0.4578)  loss_bbox_1: 1.7825 (2.4242)  loss_giou_1: 2.2054 (2.4091)  loss_ce_2: 0.4060 (0.4496)  loss_bbox_2: 1.9894 (2.5003)  loss_giou_2: 2.2495 (2.4322)  loss_ce_3: 0.4207 (0.4528)  loss_bbox_3: 1.7215 (2.4515)  loss_giou_3: 2.0077 (2.3949)  loss_ce_4: 0.4127 (0.4593)  loss_bbox_4: 1.8701 (2.4757)  loss_giou_4: 2.1592 (2.4102)  loss_ce_unscaled: 0.4233 (0.4479)  class_error_unscaled: 73.9130 (70.3173)  loss_bbox_unscaled: 0.3204 (0.4946)  loss_giou_unscaled: 0.9582 (1.2000)  cardinality_error_unscaled: 2.1250 (4.0009)  loss_ce_0_unscaled: 0.4701 (0.4185)  loss_bbox_0_unscaled: 0.3686 (0.5792)  loss_giou_0_unscaled: 1.0908 (1.3199)  cardinality_error_0_unscaled: 2.7500 (5.7323)  loss_ce_1_unscaled: 0.4150 (0.4578)  loss_bbox_1_unscaled: 0.3565 (0.4848)  loss_giou_1_unscaled: 1.1027 (1.2045)  cardinality_error_1_unscaled: 2.1250 (3.7988)  loss_ce_2_unscaled: 0.4060 (0.4496)  loss_bbox_2_unscaled: 0.3979 (0.5001)  loss_giou_2_unscaled: 1.1248 (1.2161)  cardinality_error_2_unscaled: 2.2500 (3.8440)  loss_ce_3_unscaled: 0.4207 (0.4528)  loss_bbox_3_unscaled: 0.3443 (0.4903)  loss_giou_3_unscaled: 1.0038 (1.1974)  cardinality_error_3_unscaled: 2.3750 (4.3475)  loss_ce_4_unscaled: 0.4127 (0.4593)  loss_bbox_4_unscaled: 0.3740 (0.4951)  loss_giou_4_unscaled: 1.0796 (1.2051)  cardinality_error_4_unscaled: 2.1250 (4.5310)  time: 0.3540  data: 0.0257  max mem: 8686
# Epoch: [0]  [150/437]  eta: 0:01:42  lr: 0.010000  class_error: 81.25  loss: 29.3316 (32.4524)  loss_ce: 0.4673 (0.4506)  loss_bbox: 1.8633 (2.4412)  loss_giou: 2.0360 (2.3973)  loss_ce_0: 0.6024 (0.4304)  loss_bbox_0: 1.9335 (2.8372)  loss_giou_0: 2.3089 (2.6169)  loss_ce_1: 0.4413 (0.4530)  loss_bbox_1: 2.4947 (2.4827)  loss_giou_1: 2.8073 (2.4508)  loss_ce_2: 0.3789 (0.4455)  loss_bbox_2: 2.2551 (2.5175)  loss_giou_2: 2.5728 (2.4401)  loss_ce_3: 0.4690 (0.4538)  loss_bbox_3: 1.5192 (2.3900)  loss_giou_3: 1.9429 (2.3731)  loss_ce_4: 0.4127 (0.4549)  loss_bbox_4: 1.7593 (2.4219)  loss_giou_4: 2.1592 (2.3953)  loss_ce_unscaled: 0.4673 (0.4506)  class_error_unscaled: 75.0000 (70.1636)  loss_bbox_unscaled: 0.3727 (0.4882)  loss_giou_unscaled: 1.0180 (1.1987)  cardinality_error_unscaled: 2.5000 (3.9272)  loss_ce_0_unscaled: 0.6024 (0.4304)  loss_bbox_0_unscaled: 0.3867 (0.5674)  loss_giou_0_unscaled: 1.1545 (1.3084)  cardinality_error_0_unscaled: 2.7500 (5.6523)  loss_ce_1_unscaled: 0.4413 (0.4530)  loss_bbox_1_unscaled: 0.4989 (0.4965)  loss_giou_1_unscaled: 1.4037 (1.2254)  cardinality_error_1_unscaled: 2.3750 (3.8063)  loss_ce_2_unscaled: 0.3789 (0.4455)  loss_bbox_2_unscaled: 0.4510 (0.5035)  loss_giou_2_unscaled: 1.2864 (1.2200)  cardinality_error_2_unscaled: 2.2500 (3.7724)  loss_ce_3_unscaled: 0.4690 (0.4538)  loss_bbox_3_unscaled: 0.3038 (0.4780)  loss_giou_3_unscaled: 0.9715 (1.1866)  cardinality_error_3_unscaled: 2.3750 (4.2243)  loss_ce_4_unscaled: 0.4127 (0.4549)  loss_bbox_4_unscaled: 0.3519 (0.4844)  loss_giou_4_unscaled: 1.0796 (1.1976)  cardinality_error_4_unscaled: 2.5000 (4.4180)  time: 0.3468  data: 0.0258  max mem: 8686
# Epoch: [0]  [160/437]  eta: 0:01:38  lr: 0.010000  class_error: 86.96  loss: 30.0220 (32.2629)  loss_ce: 0.4356 (0.4464)  loss_bbox: 2.1582 (2.4341)  loss_giou: 2.4357 (2.3987)  loss_ce_0: 0.5530 (0.4380)  loss_bbox_0: 2.0010 (2.7955)  loss_giou_0: 2.1535 (2.5922)  loss_ce_1: 0.3953 (0.4512)  loss_bbox_1: 2.6613 (2.4664)  loss_giou_1: 2.6413 (2.4283)  loss_ce_2: 0.3919 (0.4430)  loss_bbox_2: 2.6271 (2.5331)  loss_giou_2: 2.6404 (2.4561)  loss_ce_3: 0.4436 (0.4531)  loss_bbox_3: 1.5732 (2.3547)  loss_giou_3: 1.8890 (2.3462)  loss_ce_4: 0.4261 (0.4589)  loss_bbox_4: 1.7134 (2.3895)  loss_giou_4: 2.1388 (2.3776)  loss_ce_unscaled: 0.4356 (0.4464)  class_error_unscaled: 68.0000 (69.9341)  loss_bbox_unscaled: 0.4316 (0.4868)  loss_giou_unscaled: 1.2178 (1.1993)  cardinality_error_unscaled: 2.3750 (3.8168)  loss_ce_0_unscaled: 0.5530 (0.4380)  loss_bbox_0_unscaled: 0.4002 (0.5591)  loss_giou_0_unscaled: 1.0767 (1.2961)  cardinality_error_0_unscaled: 2.6250 (5.4790)  loss_ce_1_unscaled: 0.3953 (0.4512)  loss_bbox_1_unscaled: 0.5323 (0.4933)  loss_giou_1_unscaled: 1.3207 (1.2142)  cardinality_error_1_unscaled: 2.7500 (3.7896)  loss_ce_2_unscaled: 0.3919 (0.4430)  loss_bbox_2_unscaled: 0.5254 (0.5066)  loss_giou_2_unscaled: 1.3202 (1.2280)  cardinality_error_2_unscaled: 2.6250 (3.7019)  loss_ce_3_unscaled: 0.4436 (0.4531)  loss_bbox_3_unscaled: 0.3146 (0.4709)  loss_giou_3_unscaled: 0.9445 (1.1731)  cardinality_error_3_unscaled: 2.6250 (4.1281)  loss_ce_4_unscaled: 0.4261 (0.4589)  loss_bbox_4_unscaled: 0.3427 (0.4779)  loss_giou_4_unscaled: 1.0694 (1.1888)  cardinality_error_4_unscaled: 2.3750 (4.2818)  time: 0.3477  data: 0.0260  max mem: 8686
# Epoch: [0]  [170/437]  eta: 0:01:35  lr: 0.010000  class_error: 76.92  loss: 28.7853 (31.9024)  loss_ce: 0.3369 (0.4406)  loss_bbox: 2.1582 (2.4136)  loss_giou: 2.2530 (2.3899)  loss_ce_0: 0.4964 (0.4418)  loss_bbox_0: 2.0382 (2.7582)  loss_giou_0: 2.1236 (2.5627)  loss_ce_1: 0.3953 (0.4477)  loss_bbox_1: 1.7637 (2.4294)  loss_giou_1: 1.9617 (2.4002)  loss_ce_2: 0.3828 (0.4397)  loss_bbox_2: 2.2189 (2.5008)  loss_giou_2: 2.4470 (2.4416)  loss_ce_3: 0.4115 (0.4500)  loss_bbox_3: 1.6856 (2.3165)  loss_giou_3: 1.8709 (2.3198)  loss_ce_4: 0.4637 (0.4583)  loss_bbox_4: 1.6533 (2.3407)  loss_giou_4: 1.9859 (2.3507)  loss_ce_unscaled: 0.3369 (0.4406)  class_error_unscaled: 63.1579 (69.6594)  loss_bbox_unscaled: 0.4316 (0.4827)  loss_giou_unscaled: 1.1265 (1.1950)  cardinality_error_unscaled: 1.8750 (3.7200)  loss_ce_0_unscaled: 0.4964 (0.4418)  loss_bbox_0_unscaled: 0.4076 (0.5516)  loss_giou_0_unscaled: 1.0618 (1.2814)  cardinality_error_0_unscaled: 2.6250 (5.3238)  loss_ce_1_unscaled: 0.3953 (0.4477)  loss_bbox_1_unscaled: 0.3527 (0.4859)  loss_giou_1_unscaled: 0.9808 (1.2001)  cardinality_error_1_unscaled: 2.6250 (3.7982)  loss_ce_2_unscaled: 0.3828 (0.4397)  loss_bbox_2_unscaled: 0.4438 (0.5002)  loss_giou_2_unscaled: 1.2235 (1.2208)  cardinality_error_2_unscaled: 2.3750 (3.6053)  loss_ce_3_unscaled: 0.4115 (0.4500)  loss_bbox_3_unscaled: 0.3371 (0.4633)  loss_giou_3_unscaled: 0.9355 (1.1599)  cardinality_error_3_unscaled: 2.3750 (4.0336)  loss_ce_4_unscaled: 0.4637 (0.4583)  loss_bbox_4_unscaled: 0.3307 (0.4681)  loss_giou_4_unscaled: 0.9930 (1.1754)  cardinality_error_4_unscaled: 2.0000 (4.1667)  time: 0.3517  data: 0.0261  max mem: 8686
# Epoch: [0]  [180/437]  eta: 0:01:31  lr: 0.010000  class_error: 100.00  loss: 26.4107 (31.6673)  loss_ce: 0.3471 (0.4414)  loss_bbox: 1.8806 (2.3862)  loss_giou: 2.0781 (2.3707)  loss_ce_0: 0.4732 (0.4430)  loss_bbox_0: 2.0651 (2.7355)  loss_giou_0: 2.2466 (2.5564)  loss_ce_1: 0.4149 (0.4492)  loss_bbox_1: 1.6194 (2.3951)  loss_giou_1: 1.9435 (2.3838)  loss_ce_2: 0.3943 (0.4395)  loss_bbox_2: 1.7980 (2.4671)  loss_giou_2: 2.0734 (2.4195)  loss_ce_3: 0.3874 (0.4467)  loss_bbox_3: 1.8429 (2.3102)  loss_giou_3: 1.9805 (2.3239)  loss_ce_4: 0.4338 (0.4575)  loss_bbox_4: 1.6511 (2.3129)  loss_giou_4: 1.8139 (2.3285)  loss_ce_unscaled: 0.3471 (0.4414)  class_error_unscaled: 69.2308 (69.9048)  loss_bbox_unscaled: 0.3761 (0.4772)  loss_giou_unscaled: 1.0391 (1.1854)  cardinality_error_unscaled: 2.1250 (3.6430)  loss_ce_0_unscaled: 0.4732 (0.4430)  loss_bbox_0_unscaled: 0.4130 (0.5471)  loss_giou_0_unscaled: 1.1233 (1.2782)  cardinality_error_0_unscaled: 2.3750 (5.1892)  loss_ce_1_unscaled: 0.4149 (0.4492)  loss_bbox_1_unscaled: 0.3239 (0.4790)  loss_giou_1_unscaled: 0.9717 (1.1919)  cardinality_error_1_unscaled: 2.3750 (3.7106)  loss_ce_2_unscaled: 0.3943 (0.4395)  loss_bbox_2_unscaled: 0.3596 (0.4934)  loss_giou_2_unscaled: 1.0367 (1.2097)  cardinality_error_2_unscaled: 1.7500 (3.5262)  loss_ce_3_unscaled: 0.3874 (0.4467)  loss_bbox_3_unscaled: 0.3686 (0.4620)  loss_giou_3_unscaled: 0.9903 (1.1619)  cardinality_error_3_unscaled: 2.1250 (3.9275)  loss_ce_4_unscaled: 0.4338 (0.4575)  loss_bbox_4_unscaled: 0.3302 (0.4626)  loss_giou_4_unscaled: 0.9069 (1.1642)  cardinality_error_4_unscaled: 2.0000 (4.0656)  time: 0.3703  data: 0.0270  max mem: 8686
# Epoch: [0]  [190/437]  eta: 0:01:28  lr: 0.010000  class_error: 94.44  loss: 29.8927 (31.6741)  loss_ce: 0.4384 (0.4417)  loss_bbox: 2.2631 (2.4024)  loss_giou: 2.2628 (2.3795)  loss_ce_0: 0.5088 (0.4488)  loss_bbox_0: 1.8929 (2.6885)  loss_giou_0: 2.1860 (2.5294)  loss_ce_1: 0.4801 (0.4529)  loss_bbox_1: 1.6683 (2.3637)  loss_giou_1: 1.9856 (2.3673)  loss_ce_2: 0.4415 (0.4418)  loss_bbox_2: 1.9255 (2.4487)  loss_giou_2: 2.0816 (2.4098)  loss_ce_3: 0.4183 (0.4487)  loss_bbox_3: 2.8933 (2.4018)  loss_giou_3: 2.4828 (2.3486)  loss_ce_4: 0.4128 (0.4569)  loss_bbox_4: 2.0066 (2.3176)  loss_giou_4: 2.1133 (2.3261)  loss_ce_unscaled: 0.4384 (0.4417)  class_error_unscaled: 83.8710 (70.5005)  loss_bbox_unscaled: 0.4526 (0.4805)  loss_giou_unscaled: 1.1314 (1.1897)  cardinality_error_unscaled: 2.3750 (3.5818)  loss_ce_0_unscaled: 0.5088 (0.4488)  loss_bbox_0_unscaled: 0.3786 (0.5377)  loss_giou_0_unscaled: 1.0930 (1.2647)  cardinality_error_0_unscaled: 2.7500 (5.0792)  loss_ce_1_unscaled: 0.4801 (0.4529)  loss_bbox_1_unscaled: 0.3337 (0.4727)  loss_giou_1_unscaled: 0.9928 (1.1837)  cardinality_error_1_unscaled: 2.2500 (3.6499)  loss_ce_2_unscaled: 0.4415 (0.4418)  loss_bbox_2_unscaled: 0.3851 (0.4897)  loss_giou_2_unscaled: 1.0408 (1.2049)  cardinality_error_2_unscaled: 2.2500 (3.5216)  loss_ce_3_unscaled: 0.4183 (0.4487)  loss_bbox_3_unscaled: 0.5787 (0.4804)  loss_giou_3_unscaled: 1.2414 (1.1743)  cardinality_error_3_unscaled: 2.2500 (3.8639)  loss_ce_4_unscaled: 0.4128 (0.4569)  loss_bbox_4_unscaled: 0.4013 (0.4635)  loss_giou_4_unscaled: 1.0567 (1.1631)  cardinality_error_4_unscaled: 2.2500 (3.9935)  time: 0.3771  data: 0.0270  max mem: 8686
# Epoch: [0]  [200/437]  eta: 0:01:25  lr: 0.010000  class_error: 69.23  loss: 30.0984 (31.5613)  loss_ce: 0.4178 (0.4411)  loss_bbox: 2.1977 (2.3797)  loss_giou: 2.3729 (2.3676)  loss_ce_0: 0.4602 (0.4458)  loss_bbox_0: 1.8929 (2.6793)  loss_giou_0: 2.1485 (2.5269)  loss_ce_1: 0.4624 (0.4503)  loss_bbox_1: 1.6537 (2.3263)  loss_giou_1: 2.0297 (2.3525)  loss_ce_2: 0.4413 (0.4406)  loss_bbox_2: 1.7871 (2.4066)  loss_giou_2: 2.0648 (2.3894)  loss_ce_3: 0.4069 (0.4457)  loss_bbox_3: 3.8850 (2.4711)  loss_giou_3: 2.9597 (2.3859)  loss_ce_4: 0.4130 (0.4549)  loss_bbox_4: 1.9685 (2.2880)  loss_giou_4: 2.1914 (2.3096)  loss_ce_unscaled: 0.4178 (0.4411)  class_error_unscaled: 81.8182 (70.7509)  loss_bbox_unscaled: 0.4395 (0.4759)  loss_giou_unscaled: 1.1865 (1.1838)  cardinality_error_unscaled: 2.5000 (3.5124)  loss_ce_0_unscaled: 0.4602 (0.4458)  loss_bbox_0_unscaled: 0.3786 (0.5359)  loss_giou_0_unscaled: 1.0743 (1.2635)  cardinality_error_0_unscaled: 2.5000 (5.3078)  loss_ce_1_unscaled: 0.4624 (0.4503)  loss_bbox_1_unscaled: 0.3307 (0.4653)  loss_giou_1_unscaled: 1.0149 (1.1762)  cardinality_error_1_unscaled: 2.2500 (3.5721)  loss_ce_2_unscaled: 0.4413 (0.4406)  loss_bbox_2_unscaled: 0.3574 (0.4813)  loss_giou_2_unscaled: 1.0324 (1.1947)  cardinality_error_2_unscaled: 1.8750 (3.4509)  loss_ce_3_unscaled: 0.4069 (0.4457)  loss_bbox_3_unscaled: 0.7770 (0.4942)  loss_giou_3_unscaled: 1.4798 (1.1929)  cardinality_error_3_unscaled: 2.2500 (3.7799)  loss_ce_4_unscaled: 0.4130 (0.4549)  loss_bbox_4_unscaled: 0.3937 (0.4576)  loss_giou_4_unscaled: 1.0957 (1.1548)  cardinality_error_4_unscaled: 2.2500 (3.9061)  time: 0.3667  data: 0.0261  max mem: 9761
# Epoch: [0]  [210/437]  eta: 0:01:21  lr: 0.010000  class_error: 79.17  loss: 28.4244 (31.3862)  loss_ce: 0.4309 (0.4420)  loss_bbox: 1.9583 (2.3518)  loss_giou: 2.1081 (2.3560)  loss_ce_0: 0.5401 (0.4590)  loss_bbox_0: 2.4177 (2.6660)  loss_giou_0: 2.3625 (2.5206)  loss_ce_1: 0.3841 (0.4499)  loss_bbox_1: 1.6765 (2.3158)  loss_giou_1: 2.2414 (2.3511)  loss_ce_2: 0.4493 (0.4435)  loss_bbox_2: 1.6151 (2.3710)  loss_giou_2: 2.0466 (2.3763)  loss_ce_3: 0.4363 (0.4480)  loss_bbox_3: 3.0298 (2.4532)  loss_giou_3: 2.4843 (2.3741)  loss_ce_4: 0.4422 (0.4565)  loss_bbox_4: 1.6029 (2.2564)  loss_giou_4: 2.0005 (2.2949)  loss_ce_unscaled: 0.4309 (0.4420)  class_error_unscaled: 78.9474 (71.1692)  loss_bbox_unscaled: 0.3917 (0.4704)  loss_giou_unscaled: 1.0541 (1.1780)  cardinality_error_unscaled: 2.2500 (3.4556)  loss_ce_0_unscaled: 0.5401 (0.4590)  loss_bbox_0_unscaled: 0.4835 (0.5332)  loss_giou_0_unscaled: 1.1813 (1.2603)  cardinality_error_0_unscaled: 2.5000 (5.8685)  loss_ce_1_unscaled: 0.3841 (0.4499)  loss_bbox_1_unscaled: 0.3353 (0.4632)  loss_giou_1_unscaled: 1.1207 (1.1755)  cardinality_error_1_unscaled: 2.2500 (3.5172)  loss_ce_2_unscaled: 0.4493 (0.4435)  loss_bbox_2_unscaled: 0.3230 (0.4742)  loss_giou_2_unscaled: 1.0233 (1.1881)  cardinality_error_2_unscaled: 2.3750 (3.4271)  loss_ce_3_unscaled: 0.4363 (0.4480)  loss_bbox_3_unscaled: 0.6060 (0.4906)  loss_giou_3_unscaled: 1.2422 (1.1871)  cardinality_error_3_unscaled: 2.5000 (3.7299)  loss_ce_4_unscaled: 0.4422 (0.4565)  loss_bbox_4_unscaled: 0.3206 (0.4513)  loss_giou_4_unscaled: 1.0002 (1.1475)  cardinality_error_4_unscaled: 2.0000 (3.8318)  time: 0.3702  data: 0.0263  max mem: 9761
# Epoch: [0]  [220/437]  eta: 0:01:18  lr: 0.010000  class_error: 64.29  loss: 26.2182 (31.0844)  loss_ce: 0.4180 (0.4399)  loss_bbox: 1.6663 (2.3173)  loss_giou: 2.0273 (2.3377)  loss_ce_0: 0.5692 (0.4587)  loss_bbox_0: 2.0878 (2.6286)  loss_giou_0: 2.2390 (2.4976)  loss_ce_1: 0.4109 (0.4482)  loss_bbox_1: 1.8210 (2.2941)  loss_giou_1: 2.2090 (2.3405)  loss_ce_2: 0.4763 (0.4442)  loss_bbox_2: 1.6151 (2.3377)  loss_giou_2: 2.0629 (2.3575)  loss_ce_3: 0.4461 (0.4464)  loss_bbox_3: 1.7671 (2.4156)  loss_giou_3: 2.0508 (2.3564)  loss_ce_4: 0.4422 (0.4556)  loss_bbox_4: 1.6496 (2.2302)  loss_giou_4: 1.9735 (2.2783)  loss_ce_unscaled: 0.4180 (0.4399)  class_error_unscaled: 72.9730 (71.0966)  loss_bbox_unscaled: 0.3333 (0.4635)  loss_giou_unscaled: 1.0136 (1.1688)  cardinality_error_unscaled: 2.1250 (3.4005)  loss_ce_0_unscaled: 0.5692 (0.4587)  loss_bbox_0_unscaled: 0.4176 (0.5257)  loss_giou_0_unscaled: 1.1195 (1.2488)  cardinality_error_0_unscaled: 3.0000 (5.7477)  loss_ce_1_unscaled: 0.4109 (0.4482)  loss_bbox_1_unscaled: 0.3642 (0.4588)  loss_giou_1_unscaled: 1.1045 (1.1702)  cardinality_error_1_unscaled: 2.3750 (3.4745)  loss_ce_2_unscaled: 0.4763 (0.4442)  loss_bbox_2_unscaled: 0.3230 (0.4675)  loss_giou_2_unscaled: 1.0315 (1.1787)  cardinality_error_2_unscaled: 2.6250 (3.4214)  loss_ce_3_unscaled: 0.4461 (0.4464)  loss_bbox_3_unscaled: 0.3534 (0.4831)  loss_giou_3_unscaled: 1.0254 (1.1782)  cardinality_error_3_unscaled: 2.5000 (3.6736)  loss_ce_4_unscaled: 0.4422 (0.4556)  loss_bbox_4_unscaled: 0.3299 (0.4460)  loss_giou_4_unscaled: 0.9867 (1.1392)  cardinality_error_4_unscaled: 1.8750 (3.7817)  time: 0.3750  data: 0.0314  max mem: 9761
# Epoch: [0]  [230/437]  eta: 0:01:14  lr: 0.010000  class_error: 78.57  loss: 25.6498 (30.9341)  loss_ce: 0.4117 (0.4409)  loss_bbox: 1.6375 (2.2846)  loss_giou: 1.8763 (2.3191)  loss_ce_0: 0.4410 (0.4601)  loss_bbox_0: 1.9338 (2.6041)  loss_giou_0: 2.1446 (2.4900)  loss_ce_1: 0.3835 (0.4476)  loss_bbox_1: 1.7900 (2.2614)  loss_giou_1: 2.0826 (2.3279)  loss_ce_2: 0.4153 (0.4457)  loss_bbox_2: 1.5153 (2.3031)  loss_giou_2: 1.9377 (2.3374)  loss_ce_3: 0.4368 (0.4464)  loss_bbox_3: 1.8144 (2.4156)  loss_giou_3: 2.1083 (2.3616)  loss_ce_4: 0.4122 (0.4547)  loss_bbox_4: 1.8080 (2.2455)  loss_giou_4: 2.0613 (2.2885)  loss_ce_unscaled: 0.4117 (0.4409)  class_error_unscaled: 66.6667 (70.9227)  loss_bbox_unscaled: 0.3275 (0.4569)  loss_giou_unscaled: 0.9382 (1.1595)  cardinality_error_unscaled: 2.1250 (3.3777)  loss_ce_0_unscaled: 0.4410 (0.4601)  loss_bbox_0_unscaled: 0.3868 (0.5208)  loss_giou_0_unscaled: 1.0723 (1.2450)  cardinality_error_0_unscaled: 3.0000 (5.6477)  loss_ce_1_unscaled: 0.3835 (0.4476)  loss_bbox_1_unscaled: 0.3580 (0.4523)  loss_giou_1_unscaled: 1.0413 (1.1640)  cardinality_error_1_unscaled: 2.5000 (3.4464)  loss_ce_2_unscaled: 0.4153 (0.4457)  loss_bbox_2_unscaled: 0.3031 (0.4606)  loss_giou_2_unscaled: 0.9689 (1.1687)  cardinality_error_2_unscaled: 2.2500 (3.3869)  loss_ce_3_unscaled: 0.4368 (0.4464)  loss_bbox_3_unscaled: 0.3629 (0.4831)  loss_giou_3_unscaled: 1.0542 (1.1808)  cardinality_error_3_unscaled: 2.5000 (3.6423)  loss_ce_4_unscaled: 0.4122 (0.4547)  loss_bbox_4_unscaled: 0.3616 (0.4491)  loss_giou_4_unscaled: 1.0307 (1.1442)  cardinality_error_4_unscaled: 2.1250 (3.7224)  time: 0.3592  data: 0.0306  max mem: 9761
# Epoch: [0]  [240/437]  eta: 0:01:10  lr: 0.010000  class_error: 94.44  loss: 26.4978 (30.6955)  loss_ce: 0.4218 (0.4395)  loss_bbox: 1.5752 (2.2573)  loss_giou: 1.9288 (2.3082)  loss_ce_0: 0.3865 (0.4578)  loss_bbox_0: 2.1154 (2.5822)  loss_giou_0: 2.3197 (2.4793)  loss_ce_1: 0.4243 (0.4463)  loss_bbox_1: 1.5671 (2.2332)  loss_giou_1: 2.0298 (2.3116)  loss_ce_2: 0.4334 (0.4451)  loss_bbox_2: 1.4805 (2.2707)  loss_giou_2: 1.8997 (2.3214)  loss_ce_3: 0.3762 (0.4421)  loss_bbox_3: 1.9202 (2.3947)  loss_giou_3: 2.2703 (2.3532)  loss_ce_4: 0.4244 (0.4542)  loss_bbox_4: 1.6642 (2.2193)  loss_giou_4: 2.2922 (2.2795)  loss_ce_unscaled: 0.4218 (0.4395)  class_error_unscaled: 72.2222 (71.1112)  loss_bbox_unscaled: 0.3150 (0.4515)  loss_giou_unscaled: 0.9644 (1.1541)  cardinality_error_unscaled: 2.1250 (3.3268)  loss_ce_0_unscaled: 0.3865 (0.4578)  loss_bbox_0_unscaled: 0.4231 (0.5164)  loss_giou_0_unscaled: 1.1598 (1.2396)  cardinality_error_0_unscaled: 2.2500 (5.5166)  loss_ce_1_unscaled: 0.4243 (0.4463)  loss_bbox_1_unscaled: 0.3134 (0.4466)  loss_giou_1_unscaled: 1.0149 (1.1558)  cardinality_error_1_unscaled: 2.1250 (3.3952)  loss_ce_2_unscaled: 0.4334 (0.4451)  loss_bbox_2_unscaled: 0.2961 (0.4541)  loss_giou_2_unscaled: 0.9498 (1.1607)  cardinality_error_2_unscaled: 2.0000 (3.3434)  loss_ce_3_unscaled: 0.3762 (0.4421)  loss_bbox_3_unscaled: 0.3840 (0.4789)  loss_giou_3_unscaled: 1.1351 (1.1766)  cardinality_error_3_unscaled: 2.1250 (3.5794)  loss_ce_4_unscaled: 0.4244 (0.4542)  loss_bbox_4_unscaled: 0.3328 (0.4439)  loss_giou_4_unscaled: 1.1461 (1.1398)  cardinality_error_4_unscaled: 2.1250 (3.6680)  time: 0.3444  data: 0.0252  max mem: 9761
# Epoch: [0]  [250/437]  eta: 0:01:07  lr: 0.010000  class_error: 96.55  loss: 26.3523 (30.5584)  loss_ce: 0.4108 (0.4398)  loss_bbox: 1.6463 (2.2361)  loss_giou: 1.9019 (2.2856)  loss_ce_0: 0.3785 (0.4550)  loss_bbox_0: 2.2738 (2.6128)  loss_giou_0: 2.4278 (2.4909)  loss_ce_1: 0.4243 (0.4467)  loss_bbox_1: 1.5846 (2.2154)  loss_giou_1: 1.8229 (2.2989)  loss_ce_2: 0.4055 (0.4439)  loss_bbox_2: 1.6668 (2.2542)  loss_giou_2: 1.9637 (2.3043)  loss_ce_3: 0.3237 (0.4381)  loss_bbox_3: 1.9202 (2.3879)  loss_giou_3: 1.9663 (2.3402)  loss_ce_4: 0.4137 (0.4539)  loss_bbox_4: 1.5680 (2.1948)  loss_giou_4: 1.8008 (2.2599)  loss_ce_unscaled: 0.4108 (0.4398)  class_error_unscaled: 93.3333 (71.5973)  loss_bbox_unscaled: 0.3293 (0.4472)  loss_giou_unscaled: 0.9510 (1.1428)  cardinality_error_unscaled: 2.0000 (3.2878)  loss_ce_0_unscaled: 0.3785 (0.4550)  loss_bbox_0_unscaled: 0.4548 (0.5226)  loss_giou_0_unscaled: 1.2139 (1.2455)  cardinality_error_0_unscaled: 2.0000 (5.3845)  loss_ce_1_unscaled: 0.4243 (0.4467)  loss_bbox_1_unscaled: 0.3169 (0.4431)  loss_giou_1_unscaled: 0.9115 (1.1495)  cardinality_error_1_unscaled: 1.8750 (3.3451)  loss_ce_2_unscaled: 0.4055 (0.4439)  loss_bbox_2_unscaled: 0.3334 (0.4508)  loss_giou_2_unscaled: 0.9819 (1.1521)  cardinality_error_2_unscaled: 1.7500 (3.2918)  loss_ce_3_unscaled: 0.3237 (0.4381)  loss_bbox_3_unscaled: 0.3840 (0.4776)  loss_giou_3_unscaled: 0.9832 (1.1701)  cardinality_error_3_unscaled: 2.1250 (3.5359)  loss_ce_4_unscaled: 0.4137 (0.4539)  loss_bbox_4_unscaled: 0.3136 (0.4390)  loss_giou_4_unscaled: 0.9004 (1.1299)  cardinality_error_4_unscaled: 1.7500 (3.6091)  time: 0.3569  data: 0.0258  max mem: 9761
# Epoch: [0]  [260/437]  eta: 0:01:03  lr: 0.010000  class_error: 46.15  loss: 25.1759 (30.3598)  loss_ce: 0.4208 (0.4392)  loss_bbox: 1.6463 (2.2130)  loss_giou: 1.7880 (2.2724)  loss_ce_0: 0.3767 (0.4547)  loss_bbox_0: 2.0097 (2.5842)  loss_giou_0: 2.4168 (2.4784)  loss_ce_1: 0.4159 (0.4466)  loss_bbox_1: 1.6497 (2.2013)  loss_giou_1: 2.1728 (2.2986)  loss_ce_2: 0.3928 (0.4433)  loss_bbox_2: 1.6668 (2.2276)  loss_giou_2: 1.9637 (2.2924)  loss_ce_3: 0.3514 (0.4377)  loss_bbox_3: 1.6767 (2.3558)  loss_giou_3: 1.8976 (2.3277)  loss_ce_4: 0.3978 (0.4518)  loss_bbox_4: 1.6583 (2.1797)  loss_giou_4: 1.8907 (2.2555)  loss_ce_unscaled: 0.4208 (0.4392)  class_error_unscaled: 87.5000 (71.5935)  loss_bbox_unscaled: 0.3293 (0.4426)  loss_giou_unscaled: 0.8940 (1.1362)  cardinality_error_unscaled: 2.0000 (3.2557)  loss_ce_0_unscaled: 0.3767 (0.4547)  loss_bbox_0_unscaled: 0.4019 (0.5168)  loss_giou_0_unscaled: 1.2084 (1.2392)  cardinality_error_0_unscaled: 3.8750 (5.6461)  loss_ce_1_unscaled: 0.4159 (0.4466)  loss_bbox_1_unscaled: 0.3299 (0.4403)  loss_giou_1_unscaled: 1.0864 (1.1493)  cardinality_error_1_unscaled: 2.0000 (3.3305)  loss_ce_2_unscaled: 0.3928 (0.4433)  loss_bbox_2_unscaled: 0.3334 (0.4455)  loss_giou_2_unscaled: 0.9819 (1.1462)  cardinality_error_2_unscaled: 1.7500 (3.2567)  loss_ce_3_unscaled: 0.3514 (0.4377)  loss_bbox_3_unscaled: 0.3353 (0.4712)  loss_giou_3_unscaled: 0.9488 (1.1638)  cardinality_error_3_unscaled: 3.5000 (3.6212)  loss_ce_4_unscaled: 0.3978 (0.4518)  loss_bbox_4_unscaled: 0.3317 (0.4359)  loss_giou_4_unscaled: 0.9454 (1.1277)  cardinality_error_4_unscaled: 1.7500 (3.5589)  time: 0.3460  data: 0.0255  max mem: 9761
# ...
# Test:  [ 40/125]  eta: 0:00:19  class_error: 100.00  loss: 44.3487 (44.2969)  loss_ce: 0.4279 (0.4464)  loss_bbox: 3.1810 (3.2537)  loss_giou: 3.0431 (3.0481)  loss_ce_0: 0.4258 (0.4486)  loss_bbox_0: 4.1682 (4.2311)  loss_giou_0: 3.4052 (3.3906)  loss_ce_1: 0.4306 (0.4482)  loss_bbox_1: 3.2950 (3.3260)  loss_giou_1: 3.1113 (3.0870)  loss_ce_2: 0.4267 (0.4458)  loss_bbox_2: 4.1442 (4.2295)  loss_giou_2: 3.3275 (3.3619)  loss_ce_3: 0.4297 (0.4475)  loss_bbox_3: 3.4811 (3.5585)  loss_giou_3: 2.9955 (3.0971)  loss_ce_4: 0.4253 (0.4454)  loss_bbox_4: 3.6042 (3.7517)  loss_giou_4: 3.2989 (3.2800)  loss_ce_unscaled: 0.4279 (0.4464)  class_error_unscaled: 76.1905 (75.0371)  loss_bbox_unscaled: 0.6362 (0.6507)  loss_giou_unscaled: 1.5216 (1.5241)  cardinality_error_unscaled: 2.5000 (2.6738)  loss_ce_0_unscaled: 0.4258 (0.4486)  loss_bbox_0_unscaled: 0.8336 (0.8462)  loss_giou_0_unscaled: 1.7026 (1.6953)  cardinality_error_0_unscaled: 2.5000 (2.6738)  loss_ce_1_unscaled: 0.4306 (0.4482)  loss_bbox_1_unscaled: 0.6590 (0.6652)  loss_giou_1_unscaled: 1.5556 (1.5435)  cardinality_error_1_unscaled: 2.5000 (2.6738)  loss_ce_2_unscaled: 0.4267 (0.4458)  loss_bbox_2_unscaled: 0.8288 (0.8459)  loss_giou_2_unscaled: 1.6638 (1.6810)  cardinality_error_2_unscaled: 2.5000 (2.6738)  loss_ce_3_unscaled: 0.4297 (0.4475)  loss_bbox_3_unscaled: 0.6962 (0.7117)  loss_giou_3_unscaled: 1.4977 (1.5485)  cardinality_error_3_unscaled: 2.5000 (2.6738)  loss_ce_4_unscaled: 0.4253 (0.4454)  loss_bbox_4_unscaled: 0.7208 (0.7503)  loss_giou_4_unscaled: 1.6495 (1.6400)  cardinality_error_4_unscaled: 2.5000 (2.6738)  time: 0.2211  data: 0.0255  max mem: 13152
# Test:  [ 50/125]  eta: 0:00:17  class_error: 65.00  loss: 44.3487 (44.3904)  loss_ce: 0.4418 (0.4469)  loss_bbox: 3.2211 (3.2277)  loss_giou: 3.0230 (3.0281)  loss_ce_0: 0.4430 (0.4492)  loss_bbox_0: 4.1232 (4.2831)  loss_giou_0: 3.4232 (3.3948)  loss_ce_1: 0.4439 (0.4487)  loss_bbox_1: 3.3109 (3.2967)  loss_giou_1: 3.0360 (3.0649)  loss_ce_2: 0.4411 (0.4463)  loss_bbox_2: 4.2180 (4.2722)  loss_giou_2: 3.3569 (3.3639)  loss_ce_3: 0.4431 (0.4480)  loss_bbox_3: 3.5394 (3.5764)  loss_giou_3: 3.0636 (3.1077)  loss_ce_4: 0.4404 (0.4459)  loss_bbox_4: 3.8987 (3.7980)  loss_giou_4: 3.3707 (3.2918)  loss_ce_unscaled: 0.4418 (0.4469)  class_error_unscaled: 84.6154 (75.5171)  loss_bbox_unscaled: 0.6442 (0.6455)  loss_giou_unscaled: 1.5115 (1.5140)  cardinality_error_unscaled: 2.5000 (2.6691)  loss_ce_0_unscaled: 0.4430 (0.4492)  loss_bbox_0_unscaled: 0.8246 (0.8566)  loss_giou_0_unscaled: 1.7116 (1.6974)  cardinality_error_0_unscaled: 2.5000 (2.6691)  loss_ce_1_unscaled: 0.4439 (0.4487)  loss_bbox_1_unscaled: 0.6622 (0.6593)  loss_giou_1_unscaled: 1.5180 (1.5325)  cardinality_error_1_unscaled: 2.5000 (2.6691)  loss_ce_2_unscaled: 0.4411 (0.4463)  loss_bbox_2_unscaled: 0.8436 (0.8544)  loss_giou_2_unscaled: 1.6785 (1.6820)  cardinality_error_2_unscaled: 2.5000 (2.6691)  loss_ce_3_unscaled: 0.4431 (0.4480)  loss_bbox_3_unscaled: 0.7079 (0.7153)  loss_giou_3_unscaled: 1.5318 (1.5538)  cardinality_error_3_unscaled: 2.5000 (2.6691)  loss_ce_4_unscaled: 0.4404 (0.4459)  loss_bbox_4_unscaled: 0.7797 (0.7596)  loss_giou_4_unscaled: 1.6854 (1.6459)  cardinality_error_4_unscaled: 2.5000 (2.6691)  time: 0.2233  data: 0.0257  max mem: 13152
# Test:  [ 60/125]  eta: 0:00:14  class_error: 82.61  loss: 45.4200 (44.5338)  loss_ce: 0.4555 (0.4517)  loss_bbox: 3.2552 (3.2476)  loss_giou: 2.9424 (3.0346)  loss_ce_0: 0.4598 (0.4552)  loss_bbox_0: 4.2268 (4.2822)  loss_giou_0: 3.4662 (3.3931)  loss_ce_1: 0.4569 (0.4533)  loss_bbox_1: 3.3224 (3.3163)  loss_giou_1: 3.0000 (3.0717)  loss_ce_2: 0.4552 (0.4513)  loss_bbox_2: 4.2834 (4.2667)  loss_giou_2: 3.3734 (3.3615)  loss_ce_3: 0.4563 (0.4527)  loss_bbox_3: 3.5959 (3.6128)  loss_giou_3: 3.1839 (3.1276)  loss_ce_4: 0.4552 (0.4511)  loss_bbox_4: 3.9558 (3.8078)  loss_giou_4: 3.3642 (3.2967)  loss_ce_unscaled: 0.4555 (0.4517)  class_error_unscaled: 80.0000 (76.2713)  loss_bbox_unscaled: 0.6510 (0.6495)  loss_giou_unscaled: 1.4712 (1.5173)  cardinality_error_unscaled: 2.6250 (2.6926)  loss_ce_0_unscaled: 0.4598 (0.4552)  loss_bbox_0_unscaled: 0.8454 (0.8564)  loss_giou_0_unscaled: 1.7331 (1.6966)  cardinality_error_0_unscaled: 2.6250 (2.6926)  loss_ce_1_unscaled: 0.4569 (0.4533)  loss_bbox_1_unscaled: 0.6645 (0.6633)  loss_giou_1_unscaled: 1.5000 (1.5358)  cardinality_error_1_unscaled: 2.6250 (2.6926)  loss_ce_2_unscaled: 0.4552 (0.4513)  loss_bbox_2_unscaled: 0.8567 (0.8533)  loss_giou_2_unscaled: 1.6867 (1.6808)  cardinality_error_2_unscaled: 2.6250 (2.6926)  loss_ce_3_unscaled: 0.4563 (0.4527)  loss_bbox_3_unscaled: 0.7192 (0.7226)  loss_giou_3_unscaled: 1.5919 (1.5638)  cardinality_error_3_unscaled: 2.6250 (2.6926)  loss_ce_4_unscaled: 0.4552 (0.4511)  loss_bbox_4_unscaled: 0.7912 (0.7616)  loss_giou_4_unscaled: 1.6821 (1.6483)  cardinality_error_4_unscaled: 2.6250 (2.6926)  time: 0.2225  data: 0.0260  max mem: 13152
# Test:  [ 70/125]  eta: 0:00:12  class_error: 28.00  loss: 45.4200 (44.7341)  loss_ce: 0.4690 (0.4542)  loss_bbox: 3.3313 (3.2900)  loss_giou: 3.0975 (3.0470)  loss_ce_0: 0.4763 (0.4582)  loss_bbox_0: 4.2268 (4.2935)  loss_giou_0: 3.4662 (3.3906)  loss_ce_1: 0.4696 (0.4556)  loss_bbox_1: 3.3747 (3.3576)  loss_giou_1: 3.1204 (3.0814)  loss_ce_2: 0.4690 (0.4538)  loss_bbox_2: 4.2099 (4.2740)  loss_giou_2: 3.4021 (3.3595)  loss_ce_3: 0.4693 (0.4551)  loss_bbox_3: 3.7762 (3.6497)  loss_giou_3: 3.2005 (3.1301)  loss_ce_4: 0.4697 (0.4538)  loss_bbox_4: 3.9503 (3.8339)  loss_giou_4: 3.3172 (3.2958)  loss_ce_unscaled: 0.4690 (0.4542)  class_error_unscaled: 80.0000 (76.1219)  loss_bbox_unscaled: 0.6663 (0.6580)  loss_giou_unscaled: 1.5487 (1.5235)  cardinality_error_unscaled: 2.6250 (2.7553)  loss_ce_0_unscaled: 0.4763 (0.4582)  loss_bbox_0_unscaled: 0.8454 (0.8587)  loss_giou_0_unscaled: 1.7331 (1.6953)  cardinality_error_0_unscaled: 2.6250 (2.7553)  loss_ce_1_unscaled: 0.4696 (0.4556)  loss_bbox_1_unscaled: 0.6749 (0.6715)  loss_giou_1_unscaled: 1.5602 (1.5407)  cardinality_error_1_unscaled: 2.6250 (2.7553)  loss_ce_2_unscaled: 0.4690 (0.4538)  loss_bbox_2_unscaled: 0.8420 (0.8548)  loss_giou_2_unscaled: 1.7011 (1.6798)  cardinality_error_2_unscaled: 2.6250 (2.7553)  loss_ce_3_unscaled: 0.4693 (0.4551)  loss_bbox_3_unscaled: 0.7552 (0.7299)  loss_giou_3_unscaled: 1.6002 (1.5651)  cardinality_error_3_unscaled: 2.6250 (2.7553)  loss_ce_4_unscaled: 0.4697 (0.4538)  loss_bbox_4_unscaled: 0.7901 (0.7668)  loss_giou_4_unscaled: 1.6586 (1.6479)  cardinality_error_4_unscaled: 2.6250 (2.7553)  time: 0.2259  data: 0.0257  max mem: 13152
# Test:  [ 80/125]  eta: 0:00:10  class_error: 92.31  loss: 45.4153 (44.6942)  loss_ce: 0.4690 (0.4574)  loss_bbox: 3.2437 (3.2502)  loss_giou: 3.0347 (3.0384)  loss_ce_0: 0.4763 (0.4621)  loss_bbox_0: 4.4123 (4.3076)  loss_giou_0: 3.4732 (3.4018)  loss_ce_1: 0.4696 (0.4586)  loss_bbox_1: 3.2995 (3.3128)  loss_giou_1: 3.0419 (3.0708)  loss_ce_2: 0.4690 (0.4571)  loss_bbox_2: 4.2912 (4.2945)  loss_giou_2: 3.4150 (3.3709)  loss_ce_3: 0.4693 (0.4581)  loss_bbox_3: 3.6450 (3.6201)  loss_giou_3: 3.1053 (3.1305)  loss_ce_4: 0.4697 (0.4572)  loss_bbox_4: 3.9007 (3.8386)  loss_giou_4: 3.3627 (3.3078)  loss_ce_unscaled: 0.4690 (0.4574)  class_error_unscaled: 92.3077 (77.8119)  loss_bbox_unscaled: 0.6487 (0.6500)  loss_giou_unscaled: 1.5174 (1.5192)  cardinality_error_unscaled: 2.6250 (2.7269)  loss_ce_0_unscaled: 0.4763 (0.4621)  loss_bbox_0_unscaled: 0.8825 (0.8615)  loss_giou_0_unscaled: 1.7366 (1.7009)  cardinality_error_0_unscaled: 2.6250 (2.7269)  loss_ce_1_unscaled: 0.4696 (0.4586)  loss_bbox_1_unscaled: 0.6599 (0.6626)  loss_giou_1_unscaled: 1.5209 (1.5354)  cardinality_error_1_unscaled: 2.6250 (2.7269)  loss_ce_2_unscaled: 0.4690 (0.4571)  loss_bbox_2_unscaled: 0.8582 (0.8589)  loss_giou_2_unscaled: 1.7075 (1.6854)  cardinality_error_2_unscaled: 2.6250 (2.7269)  loss_ce_3_unscaled: 0.4693 (0.4581)  loss_bbox_3_unscaled: 0.7290 (0.7240)  loss_giou_3_unscaled: 1.5526 (1.5652)  cardinality_error_3_unscaled: 2.6250 (2.7269)  loss_ce_4_unscaled: 0.4697 (0.4572)  loss_bbox_4_unscaled: 0.7801 (0.7677)  loss_giou_4_unscaled: 1.6813 (1.6539)  cardinality_error_4_unscaled: 2.6250 (2.7269)  time: 0.2269  data: 0.0256  max mem: 13152
# Test:  [ 90/125]  eta: 0:00:08  class_error: 85.00  loss: 45.2559 (44.7401)  loss_ce: 0.4555 (0.4600)  loss_bbox: 3.2340 (3.2617)  loss_giou: 3.0268 (3.0416)  loss_ce_0: 0.4598 (0.4653)  loss_bbox_0: 4.2413 (4.3119)  loss_giou_0: 3.4492 (3.3980)  loss_ce_1: 0.4569 (0.4611)  loss_bbox_1: 3.2972 (3.3261)  loss_giou_1: 3.0097 (3.0744)  loss_ce_2: 0.4552 (0.4598)  loss_bbox_2: 4.2251 (4.2973)  loss_giou_2: 3.3972 (3.3670)  loss_ce_3: 0.4563 (0.4606)  loss_bbox_3: 3.4578 (3.6230)  loss_giou_3: 3.0942 (3.1230)  loss_ce_4: 0.4552 (0.4600)  loss_bbox_4: 3.8405 (3.8457)  loss_giou_4: 3.3642 (3.3037)  loss_ce_unscaled: 0.4555 (0.4600)  class_error_unscaled: 85.0000 (78.0601)  loss_bbox_unscaled: 0.6468 (0.6523)  loss_giou_unscaled: 1.5134 (1.5208)  cardinality_error_unscaled: 2.6250 (2.7582)  loss_ce_0_unscaled: 0.4598 (0.4653)  loss_bbox_0_unscaled: 0.8483 (0.8624)  loss_giou_0_unscaled: 1.7246 (1.6990)  cardinality_error_0_unscaled: 2.6250 (2.7582)  loss_ce_1_unscaled: 0.4569 (0.4611)  loss_bbox_1_unscaled: 0.6594 (0.6652)  loss_giou_1_unscaled: 1.5048 (1.5372)  cardinality_error_1_unscaled: 2.6250 (2.7582)  loss_ce_2_unscaled: 0.4552 (0.4598)  loss_bbox_2_unscaled: 0.8450 (0.8595)  loss_giou_2_unscaled: 1.6986 (1.6835)  cardinality_error_2_unscaled: 2.6250 (2.7582)  loss_ce_3_unscaled: 0.4563 (0.4606)  loss_bbox_3_unscaled: 0.6916 (0.7246)  loss_giou_3_unscaled: 1.5471 (1.5615)  cardinality_error_3_unscaled: 2.6250 (2.7582)  loss_ce_4_unscaled: 0.4552 (0.4600)  loss_bbox_4_unscaled: 0.7681 (0.7691)  loss_giou_4_unscaled: 1.6821 (1.6519)  cardinality_error_4_unscaled: 2.6250 (2.7582)  time: 0.2229  data: 0.0255  max mem: 13152
# Test:  [100/125]  eta: 0:00:05  class_error: 87.88  loss: 45.4142 (44.8279)  loss_ce: 0.4555 (0.4598)  loss_bbox: 3.2994 (3.2692)  loss_giou: 3.0777 (3.0447)  loss_ce_0: 0.4598 (0.4650)  loss_bbox_0: 4.4343 (4.3379)  loss_giou_0: 3.4412 (3.3940)  loss_ce_1: 0.4569 (0.4609)  loss_bbox_1: 3.3622 (3.3338)  loss_giou_1: 3.0934 (3.0767)  loss_ce_2: 0.4552 (0.4595)  loss_bbox_2: 4.3877 (4.3212)  loss_giou_2: 3.4093 (3.3643)  loss_ce_3: 0.4563 (0.4604)  loss_bbox_3: 3.6470 (3.6353)  loss_giou_3: 3.1003 (3.1205)  loss_ce_4: 0.4552 (0.4598)  loss_bbox_4: 3.9404 (3.8652)  loss_giou_4: 3.3125 (3.2998)  loss_ce_unscaled: 0.4555 (0.4598)  class_error_unscaled: 80.0000 (77.7106)  loss_bbox_unscaled: 0.6599 (0.6538)  loss_giou_unscaled: 1.5389 (1.5223)  cardinality_error_unscaled: 2.7500 (2.7574)  loss_ce_0_unscaled: 0.4598 (0.4650)  loss_bbox_0_unscaled: 0.8869 (0.8676)  loss_giou_0_unscaled: 1.7206 (1.6970)  cardinality_error_0_unscaled: 2.7500 (2.7574)  loss_ce_1_unscaled: 0.4569 (0.4609)  loss_bbox_1_unscaled: 0.6724 (0.6668)  loss_giou_1_unscaled: 1.5467 (1.5383)  cardinality_error_1_unscaled: 2.7500 (2.7574)  loss_ce_2_unscaled: 0.4552 (0.4595)  loss_bbox_2_unscaled: 0.8775 (0.8642)  loss_giou_2_unscaled: 1.7046 (1.6821)  cardinality_error_2_unscaled: 2.7500 (2.7574)  loss_ce_3_unscaled: 0.4563 (0.4604)  loss_bbox_3_unscaled: 0.7294 (0.7271)  loss_giou_3_unscaled: 1.5501 (1.5603)  cardinality_error_3_unscaled: 2.7500 (2.7574)  loss_ce_4_unscaled: 0.4552 (0.4598)  loss_bbox_4_unscaled: 0.7881 (0.7730)  loss_giou_4_unscaled: 1.6562 (1.6499)  cardinality_error_4_unscaled: 2.7500 (2.7574)  time: 0.2220  data: 0.0256  max mem: 13152
# Test:  [110/125]  eta: 0:00:03  class_error: 77.78  loss: 45.4142 (45.0097)  loss_ce: 0.4555 (0.4620)  loss_bbox: 3.3349 (3.2928)  loss_giou: 3.0170 (3.0470)  loss_ce_0: 0.4598 (0.4678)  loss_bbox_0: 4.5348 (4.3603)  loss_giou_0: 3.4412 (3.3962)  loss_ce_1: 0.4569 (0.4630)  loss_bbox_1: 3.3997 (3.3573)  loss_giou_1: 3.0600 (3.0794)  loss_ce_2: 0.4552 (0.4618)  loss_bbox_2: 4.4530 (4.3390)  loss_giou_2: 3.4093 (3.3653)  loss_ce_3: 0.4563 (0.4626)  loss_bbox_3: 3.7297 (3.6698)  loss_giou_3: 3.1170 (3.1265)  loss_ce_4: 0.4552 (0.4622)  loss_bbox_4: 3.9959 (3.8942)  loss_giou_4: 3.3173 (3.3025)  loss_ce_unscaled: 0.4555 (0.4620)  class_error_unscaled: 81.2500 (78.4664)  loss_bbox_unscaled: 0.6670 (0.6586)  loss_giou_unscaled: 1.5085 (1.5235)  cardinality_error_unscaled: 2.6250 (2.7534)  loss_ce_0_unscaled: 0.4598 (0.4678)  loss_bbox_0_unscaled: 0.9070 (0.8721)  loss_giou_0_unscaled: 1.7206 (1.6981)  cardinality_error_0_unscaled: 2.6250 (2.7534)  loss_ce_1_unscaled: 0.4569 (0.4630)  loss_bbox_1_unscaled: 0.6799 (0.6715)  loss_giou_1_unscaled: 1.5300 (1.5397)  cardinality_error_1_unscaled: 2.6250 (2.7534)  loss_ce_2_unscaled: 0.4552 (0.4618)  loss_bbox_2_unscaled: 0.8906 (0.8678)  loss_giou_2_unscaled: 1.7046 (1.6827)  cardinality_error_2_unscaled: 2.6250 (2.7534)  loss_ce_3_unscaled: 0.4563 (0.4626)  loss_bbox_3_unscaled: 0.7459 (0.7340)  loss_giou_3_unscaled: 1.5585 (1.5633)  cardinality_error_3_unscaled: 2.6250 (2.7534)  loss_ce_4_unscaled: 0.4552 (0.4622)  loss_bbox_4_unscaled: 0.7992 (0.7788)  loss_giou_4_unscaled: 1.6586 (1.6512)  cardinality_error_4_unscaled: 2.6250 (2.7534)  time: 0.2247  data: 0.0261  max mem: 13152
# ^C
# Traceback (most recent call last):
#   File "/home/epanagiotou/AdvancedNLP/DETR_reimplementation/detr/main.py", line 250, in <module>
#     main(args)
#   File "/home/epanagiotou/AdvancedNLP/DETR_reimplementation/detr/main.py", line 216, in main
#     test_stats, coco_evaluator = evaluate(
#   File "/home/epanagiotou/anaconda3/envs/cs769/lib/python3.10/site-packages/torch/utils/_contextlib.py", line 116, in decorate_context
#     return func(*args, **kwargs)
#   File "/home/epanagiotou/AdvancedNLP/DETR_reimplementation/detr/engine.py", line 93, in evaluate
#     loss_dict = criterion(outputs, targets)
#   File "/home/epanagiotou/anaconda3/envs/cs769/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/home/epanagiotou/anaconda3/envs/cs769/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1747, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/home/epanagiotou/AdvancedNLP/DETR_reimplementation/detr/models/detr.py", line 225, in forward
#     indices = self.matcher(outputs_without_aux, targets)
#   File "/home/epanagiotou/anaconda3/envs/cs769/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1736, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/home/epanagiotou/anaconda3/envs/cs769/lib/python3.10/site-packages/torch/nn/modules/module.py", line 1747, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/home/epanagiotou/anaconda3/envs/cs769/lib/python3.10/site-packages/torch/utils/_contextlib.py", line 116, in decorate_context
#     return func(*args, **kwargs)
#   File "/home/epanagiotou/AdvancedNLP/DETR_reimplementation/detr/models/matcher.py", line 74, in forward
#     cost_giou = -generalized_box_iou(box_cxcywh_to_xyxy(out_bbox), box_cxcywh_to_xyxy(tgt_bbox))
#   File "/home/epanagiotou/AdvancedNLP/DETR_reimplementation/detr/util/box_ops.py", line 51, in generalized_box_iou
#     assert (boxes1[:, 2:] >= boxes1[:, :2]).all()
# KeyboardInterrupt

# %%
# %%

model = torch.hub.load('facebookresearch/detr',
                       'detr_resnet50',
                       pretrained=False,
                       num_classes=num_classes)

checkpoint = torch.load('/home/lefki/ECE766/helmet_detr/output/checkpoint.pth',
                        map_location='cpu')

model.load_state_dict(checkpoint['model'],
                      strict=False)

model.eval();
# Out:
# Downloading: "https://github.com/facebookresearch/detr/zipball/main" to /home/epanagiotou/.cache/torch/hub/main.zip
# /home/epanagiotou/anaconda3/envs/cs769/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/epanagiotou/anaconda3/envs/cs769/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# /tmp/ipykernel_440927/1872169425.py:8: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load('/home/lefki/ECE766/helmet_detr/output/checkpoint.pth',
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 8
#       1 # %%
#       3 model = torch.hub.load('facebookresearch/detr',
#       4                        'detr_resnet50',
#       5                        pretrained=False,
#       6                        num_classes=num_classes)
# ----> 8 checkpoint = torch.load('/home/lefki/ECE766/helmet_detr/output/checkpoint.pth',
#       9                         map_location='cpu')
#      11 model.load_state_dict(checkpoint['model'],
#      12                       strict=False)
#      14 model.eval();
#
# File ~/anaconda3/envs/cs769/lib/python3.10/site-packages/torch/serialization.py:1319, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1316 if "encoding" not in pickle_load_args.keys():
#    1317     pickle_load_args["encoding"] = "utf-8"
# -> 1319 with _open_file_like(f, "rb") as opened_file:
#    1320     if _is_zipfile(opened_file):
#    1321         # The zipfile reader is going to advance the current file position.
#    1322         # If we want to actually tail call to torch.jit.load, we need to
#    1323         # reset back to the original position.
#    1324         orig_position = opened_file.tell()
#
# File ~/anaconda3/envs/cs769/lib/python3.10/site-packages/torch/serialization.py:659, in _open_file_like(name_or_buffer, mode)
#     657 def _open_file_like(name_or_buffer, mode):
#     658     if _is_path(name_or_buffer):
# --> 659         return _open_file(name_or_buffer, mode)
#     660     else:
#     661         if "w" in mode:
#
# File ~/anaconda3/envs/cs769/lib/python3.10/site-packages/torch/serialization.py:640, in _open_file.__init__(self, name, mode)
#     639 def __init__(self, name, mode):
# --> 640     super().__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/lefki/ECE766/helmet_detr/output/checkpoint.pth'

# %%
# %%

# colors for visualization
COLORS = [[0.000, 0.447, 0.741], [0.850, 0.325, 0.098], [0.929, 0.694, 0.125],
          [0.494, 0.184, 0.556], [0.466, 0.674, 0.188], [0.301, 0.745, 0.933]]

# %%
# %%

def plot_finetuned_results(pil_img, prob=None, boxes=None):
    plt.figure(figsize=(16,10))
    plt.imshow(pil_img)
    ax = plt.gca()
    colors = COLORS * 100
    if prob is not None and boxes is not None:
      for p, (xmin, ymin, xmax, ymax), c in zip(prob, boxes.tolist(), colors):
          ax.add_patch(plt.Rectangle((xmin, ymin), xmax - xmin, ymax - ymin,
                                    fill=False, color=c, linewidth=3))
          cl = p.argmax()
          text = f'{finetuned_classes[cl]}: {p[cl]:0.2f}'
          ax.text(xmin, ymin, text, fontsize=15,
                  bbox=dict(facecolor='yellow', alpha=0.5))
    plt.axis('off')
    plt.show()

# %%
# %%

import torchvision.transforms as T

# standard PyTorch mean-std input image normalization
transform = T.Compose([
    T.Resize(800),
    T.ToTensor(),
    T.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# for output bounding box post-processing
def box_cxcywh_to_xyxy(x):
    x_c, y_c, w, h = x.unbind(1)
    b = [(x_c - 0.5 * w), (y_c - 0.5 * h),
         (x_c + 0.5 * w), (y_c + 0.5 * h)]
    return torch.stack(b, dim=1)

def rescale_bboxes(out_bbox, size):
    img_w, img_h = size
    b = box_cxcywh_to_xyxy(out_bbox)
    b = b * torch.tensor([img_w, img_h, img_w, img_h], dtype=torch.float32)
    return b

# %%
# %%

def filter_bboxes_from_outputs(outputs,
                               threshold=0.7):
  
  # keep only predictions with confidence above threshold
  probas = outputs['pred_logits'].softmax(-1)[0, :, :-1]
  keep = probas.max(-1).values > threshold

  probas_to_keep = probas[keep]

  # convert boxes from [0; 1] to image scales
  bboxes_scaled = rescale_bboxes(outputs['pred_boxes'][0, keep], im.size)
  
  return probas_to_keep, bboxes_scaled

# %%
# %%

def run_worflow(my_image, my_model):
  # mean-std normalize the input image (batch-size: 1)
  img = transform(my_image).unsqueeze(0)

  # propagate through the model
  outputs = my_model(img)

  for threshold in [0.8]:
    
    probas_to_keep, bboxes_scaled = filter_bboxes_from_outputs(outputs,
                                                              threshold=threshold)

    plot_finetuned_results(my_image,
                           probas_to_keep, 
                           bboxes_scaled)

# %%
# Visualize predictions

from PIL import Image
img_name = '/home/lefki/ECE766/helmet_detr/test_images/hard_hat_workers32.png'
# img_name = '/home/lefki/ECE766/helmet_detr/test_images/hard_hat_workers84.png'
# img_name = '/home/lefki/ECE766/helmet_detr/test_images/hard_hat_workers499.png'
# img_name = '/home/lefki/ECE766/helmet_detr/test_images/hard_hat_workers2459.png'
# img_name = '/home/lefki/ECE766/helmet_detr/test_images/hard_hat_workers4839.png'
im = Image.open(img_name)

run_worflow(im,
            model)
